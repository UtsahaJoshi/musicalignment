# %% [markdown]
# # Creating Piano Rolls from MusicXML or MIDI files

# %%
import os
# Uncomment this line if the kernel keeps crashing
# See https://stackoverflow.com/a/53014308
# os.environ['KMP_DUPLICATE_LIB_OK']='True'

import partitura as pt
import matplotlib.pyplot as plt

# %config InlineBackend.figure_format ='retina'

# %%
path_to_musicxml = os.path.join("..","introduction","example_data","Chopin_op10_no3.musicxml")
part = pt.load_musicxml(path_to_musicxml)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In [6], line 2
#       1 path_to_musicxml = os.path.join("..","introduction","example_file","filename.mid")
# ----> 2 part = pt.load_musicxml(path_to_musicxml)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\partitura\utils\misc.py:49, in deprecated_alias.<locals>.deco.<locals>.wrapper(*args, **kwargs)
#      46 @functools.wraps(f)
#      47 def wrapper(*args, **kwargs):
#      48     rename_kwargs(f.__name__, kwargs, aliases)
# ---> 49     return f(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\partitura\utils\misc.py:71, in deprecated_parameter.<locals>.deco.<locals>.wrapper(*args, **kwargs)
#      68 @functools.wraps(f)
#      69 def wrapper(*args, **kwargs):
#      70     to_be_deprecated(f.__name__, kwargs, deprecated_kwargs)
# ---> 71     return f(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\partitura\io\importmusicxml.py:218, in load_musicxml(filename, validate, force_note_ids)
#     210         xml.seek(0)
#     212 parser = etree.XMLParser(
#     213     resolve_entities=False,
#     214     huge_tree=False,
#     215     remove_comments=True,
#     216     remove_blank_text=True,
#     217 )
# --> 218 document = etree.parse(xml, parser)
#     220 if document.getroot().tag != "score-partwise":
#     221     raise Exception("Currently only score-partwise structure is supported")
#
# File src\lxml\etree.pyx:3538, in lxml.etree.parse()
#
# File src\lxml\parser.pxi:1876, in lxml.etree._parseDocument()
#
# File src\lxml\parser.pxi:1902, in lxml.etree._parseDocumentFromURL()
#
# File src\lxml\parser.pxi:1805, in lxml.etree._parseDocFromFile()
#
# File src\lxml\parser.pxi:1177, in lxml.etree._BaseParser._parseDocFromFile()
#
# File src\lxml\parser.pxi:615, in lxml.etree._ParserContext._handleParseResultDoc()
#
# File src\lxml\parser.pxi:725, in lxml.etree._handleParseResult()
#
# File src\lxml\parser.pxi:652, in lxml.etree._raiseParseError()
#
# OSError: Error reading file '..\introduction\example_file\filename.mid': failed to load external entity "../introduction/example_file/filename.mid"

# %%
piano_roll = pt.utils.music.compute_pianoroll(part)

# %%
piano_roll
# Out:
# <128x332 sparse matrix of type '<class 'numpy.intc'>'
# 	with 1414 stored elements in Compressed Sparse Column format>

# %%
# %matplotlib inline
plt.imshow(piano_roll.todense(), aspect = "auto", origin="lower", cmap="gray")

# %% [markdown]
# ## possible modifications:
#
# - pitch margins
# - time margins
# - note encodings (onset only, fixed level, exponential/linear decay...)
# - offset encodings (how do you know that two consecutive notes are two notes instead of 1 long one?)
# - time unit and its sample rate
#
#
# ## Exercise: draw the piano roll of the performance MIDI file (example_file/filename.mid) to a piano roll with time unit in seconds, with 4 samples per second, where only the onsets are encoding (single pixel width per note)!
#
# hint: check https://github.com/CPJKU/partitura/blob/master/partitura/utils/music.py

# %%
# your code here...
