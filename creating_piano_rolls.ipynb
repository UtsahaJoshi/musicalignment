# %% [markdown]
# # Creating Piano Rolls from MusicXML or MIDI files

# %%
import os
# Uncomment this line if the kernel keeps crashing
# See https://stackoverflow.com/a/53014308
# os.environ['KMP_DUPLICATE_LIB_OK']='True'

import partitura as pt
import matplotlib.pyplot as plt

# %config InlineBackend.figure_format ='retina'

# %%
path_to_musicxml = os.path.join("..","introduction","example_data","Chopin_op10_no3_p01.mid")
part = pt.load_score_midi(path_to_musicxml)
# Out:
# C:\Users\Ripple\AppData\Local\Programs\Python\Python39\lib\site-packages\partitura\io\importmidi.py:455: UserWarning: pitch spelling
#   warnings.warn("pitch spelling")
# C:\Users\Ripple\AppData\Local\Programs\Python\Python39\lib\site-packages\partitura\utils\misc.py:49: UserWarning: voice estimation
#   return f(*args, **kwargs)
# C:\Users\Ripple\AppData\Local\Programs\Python\Python39\lib\site-packages\partitura\io\importmidi.py:516: UserWarning: create_part
#   part = create_part(
# C:\Users\Ripple\AppData\Local\Programs\Python\Python39\lib\site-packages\partitura\io\importmidi.py:516: UserWarning: add notes
#   part = create_part(
# C:\Users\Ripple\AppData\Local\Programs\Python\Python39\lib\site-packages\partitura\io\importmidi.py:683: UserWarning: No time signatures found, assuming 4/4
#   warnings.warn("No time signatures found, assuming 4/4")
# C:\Users\Ripple\AppData\Local\Programs\Python\Python39\lib\site-packages\partitura\io\importmidi.py:516: UserWarning: add time sigs and measures
#   part = create_part(
# C:\Users\Ripple\AppData\Local\Programs\Python\Python39\lib\site-packages\partitura\io\importmidi.py:516: UserWarning: tie notes
#   part = create_part(
# C:\Users\Ripple\AppData\Local\Programs\Python\Python39\lib\site-packages\partitura\io\importmidi.py:516: UserWarning: find tuplets
#   part = create_part(
# C:\Users\Ripple\AppData\Local\Programs\Python\Python39\lib\site-packages\partitura\io\importmidi.py:516: UserWarning: done create_part
#   part = create_part(

# %%
piano_roll = pt.utils.music.compute_pianoroll(part)

# %%
print(piano_roll)
# Out:
#   (59, 0)	1
#   (59, 1)	1
#   (59, 2)	1
#   (59, 3)	1
#   (40, 11)	1
#   (64, 11)	1
#   (40, 12)	1
#   (64, 12)	1
#   (40, 13)	1
#   (56, 13)	1
#   (64, 13)	1
#   (40, 14)	1
#   (56, 14)	1
#   (64, 14)	1
#   (40, 15)	1
#   (56, 15)	1
#   (64, 15)	1
#   (40, 16)	1
#   (56, 16)	1
#   (64, 16)	1
#   (40, 17)	1
#   (56, 17)	1
#   (64, 17)	1
#   (40, 18)	1
#   (56, 18)	1
#   :	:
#   (40, 1325)	1
#   (47, 1325)	1
#   (52, 1325)	1
#   (56, 1325)	1
#   (64, 1325)	1
#   (40, 1326)	1
#   (47, 1326)	1
#   (52, 1326)	1
#   (56, 1326)	1
#   (64, 1326)	1
#   (40, 1327)	1
#   (47, 1327)	1
#   (52, 1327)	1
#   (56, 1327)	1
#   (64, 1327)	1
#   (40, 1328)	1
#   (47, 1328)	1
#   (52, 1328)	1
#   (64, 1328)	1
#   (47, 1329)	1
#   (52, 1329)	1
#   (64, 1329)	1
#   (47, 1330)	1
#   (52, 1330)	1
#   (64, 1330)	1

# %%
# %matplotlib inline
plt.imshow(piano_roll.todense(), aspect = "auto", origin="lower", cmap="gray")

# %% [markdown]
# ## possible modifications:
#
# - pitch margins
# - time margins
# - note encodings (onset only, fixed level, exponential/linear decay...)
# - offset encodings (how do you know that two consecutive notes are two notes instead of 1 long one?)
# - time unit and its sample rate
#
#
# ## Exercise: draw the piano roll of the performance MIDI file (example_file/filename.mid) to a piano roll with time unit in seconds, with 4 samples per second, where only the onsets are encoding (single pixel width per note)!
#
# hint: check https://github.com/CPJKU/partitura/blob/master/partitura/utils/music.py

# %%
# your code here...
