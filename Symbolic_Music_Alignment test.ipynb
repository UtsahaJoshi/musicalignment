# %% [markdown]
# # Symbolic Music Alignment

# %% [markdown]
# ## Music Alignment
#
# Music alignment is a process of matching a note in a musical performance to the corresponding note in the score. It can be efficiently done using tools which have a note alignment algorithm and the user is equipped with an interface to visually observe and interact with the alignment result.

# %% [markdown]
# ## Music Representation
#
# Symbolic music representation contains musical notations to model/ represent a music score in a visual manner. It also contains valuable audio information (like note onsets, pitch, duration, etc) related to the particular musical piece.

# %%
# Import things that you need
import numpy as np
import partitura as pt
import matplotlib.pyplot as plt
from MilesDavies_Alignment import *

# %% [markdown]
# ## Feature Representations
#
# * Which features did you use?
# * Which elements of the music do they capture?
# * Was there any pre-processing of the features?
# * Anything that you think relevant.
# * Make sure to include plots and visualizations!

# %%
# 1. Load the data
dataset = load_dataset('../../training set')
alignments = []
evaluation = []
piece_names = []
for i, (piece_name, pdata) in enumerate(dataset.items()):
    piece_names.append(piece_name)
    performance_note_array, score_note_array, gt_alignment = pdata

    score_features, score_idx = compute_pianoroll_score(
        score_note_array=score_note_array,
        time_div="auto",
    )
    print(score_features.size)

    performance_features, performance_idx = compute_pianoroll_performance(
        performance_note_array=performance_note_array,
        time_div="auto",
    )
    # 3. Compute the alignment (Adapt this part as needed!)
    warping_path, _ = fast_dynamic_time_warping(
        X=score_features,
        Y=performance_features,
        metric="euclidean",
    )

    predicted_alignment = greedy_note_alignment(
        warping_path=warping_path,
        idx1=score_idx,
        note_array1=score_note_array,
        idx2=performance_idx,
        note_array2=performance_note_array,
    )
        

    # Compute evaluation (Do not change this)
    alignments.append(predicted_alignment)

    piece_eval = compare_alignments(
        prediction=predicted_alignment,
        ground_truth=gt_alignment,
    )

    print(
        f"{i+1}/{len(dataset)} {piece_name}: "
        f"F-score:{piece_eval[2]:.2f} "
        f"Precision:{piece_eval[0]:.2f} "
        f"Recall:{piece_eval[1]:.2f}"
    )

    evaluation.append(piece_eval)

# compute mean evaluation
mean_eval = np.mean(evaluation, 0)

print(
    "\n\nAverage Performance over the dataset\n"
    f"F-score:{mean_eval[2]:.2f}\t"
    f"Precision:{mean_eval[0]:.2f}\t",
    f"Recall:{mean_eval[1]:.2f}",
)
# Out:
# 29216
# 1/88 Chopin_op10_no3_p01: F-score:0.86 Precision:0.83 Recall:0.90
# 29216
# 2/88 Chopin_op10_no3_p02: F-score:0.85 Precision:0.82 Recall:0.89
# 29216
# 3/88 Chopin_op10_no3_p03: F-score:0.84 Precision:0.80 Recall:0.89
# 29216
# 4/88 Chopin_op10_no3_p04: F-score:0.87 Precision:0.84 Recall:0.90
# 29216
# 5/88 Chopin_op10_no3_p05: F-score:0.96 Precision:0.95 Recall:0.97
# 29216
# 6/88 Chopin_op10_no3_p06: F-score:0.75 Precision:0.70 Recall:0.81
# 29216
# 7/88 Chopin_op10_no3_p07: F-score:0.76 Precision:0.72 Recall:0.81
# 29216
# 8/88 Chopin_op10_no3_p08: F-score:0.84 Precision:0.80 Recall:0.88
# 29216
# 9/88 Chopin_op10_no3_p09: F-score:0.92 Precision:0.90 Recall:0.94
# 29216
# 10/88 Chopin_op10_no3_p10: F-score:0.82 Precision:0.79 Recall:0.86
# 29216
# 11/88 Chopin_op10_no3_p11: F-score:0.98 Precision:0.97 Recall:0.99
# 29216
# 12/88 Chopin_op10_no3_p12: F-score:0.81 Precision:0.77 Recall:0.85
# 29216
# 13/88 Chopin_op10_no3_p13: F-score:0.86 Precision:0.82 Recall:0.90
# 29216
# 14/88 Chopin_op10_no3_p14: F-score:0.77 Precision:0.72 Recall:0.81
# 29216
# 15/88 Chopin_op10_no3_p15: F-score:0.94 Precision:0.92 Recall:0.95
# 29216
# 16/88 Chopin_op10_no3_p16: F-score:0.91 Precision:0.89 Recall:0.93
# 29216
# 17/88 Chopin_op10_no3_p17: F-score:0.90 Precision:0.88 Recall:0.92
# 29216
# 18/88 Chopin_op10_no3_p18: F-score:0.82 Precision:0.79 Recall:0.85
# 29216
# 19/88 Chopin_op10_no3_p19: F-score:0.84 Precision:0.81 Recall:0.88
# 29216
# 20/88 Chopin_op10_no3_p20: F-score:0.93 Precision:0.91 Recall:0.95
# 29216
# 21/88 Chopin_op10_no3_p21: F-score:0.82 Precision:0.79 Recall:0.87
# 29216
# 22/88 Chopin_op10_no3_p22: F-score:0.75 Precision:0.70 Recall:0.80
# 192896
# 23/88 Chopin_op38_p01: F-score:0.77 Precision:0.72 Recall:0.81
# 192896
# 24/88 Chopin_op38_p02: F-score:0.78 Precision:0.74 Recall:0.82
# 192896
# 25/88 Chopin_op38_p03: F-score:0.71 Precision:0.67 Recall:0.76
# 192896
# 26/88 Chopin_op38_p04: F-score:0.81 Precision:0.77 Recall:0.85
# 192896
# 27/88 Chopin_op38_p05: F-score:0.83 Precision:0.80 Recall:0.87
# 192896
# 28/88 Chopin_op38_p06: F-score:0.70 Precision:0.64 Recall:0.76
# 192896
# 29/88 Chopin_op38_p07: F-score:0.78 Precision:0.73 Recall:0.84
# 192896
# 30/88 Chopin_op38_p08: F-score:0.76 Precision:0.72 Recall:0.81
# 192896
# 31/88 Chopin_op38_p09: F-score:0.83 Precision:0.80 Recall:0.87
# 192896
# 32/88 Chopin_op38_p10: F-score:0.77 Precision:0.73 Recall:0.82
# 192896
# 33/88 Chopin_op38_p11: F-score:0.79 Precision:0.75 Recall:0.84
# 192896
# 34/88 Chopin_op38_p12: F-score:0.76 Precision:0.72 Recall:0.81
# 192896
# 35/88 Chopin_op38_p13: F-score:0.74 Precision:0.69 Recall:0.79
# 192896
# 36/88 Chopin_op38_p14: F-score:0.79 Precision:0.75 Recall:0.83
# 192896
# 37/88 Chopin_op38_p15: F-score:0.70 Precision:0.65 Recall:0.76
# 192896
# 38/88 Chopin_op38_p16: F-score:0.74 Precision:0.69 Recall:0.79
# 192896
# 39/88 Chopin_op38_p17: F-score:0.80 Precision:0.76 Recall:0.85
# 192896
# 40/88 Chopin_op38_p18: F-score:0.72 Precision:0.68 Recall:0.77
# 192896
# 41/88 Chopin_op38_p19: F-score:0.85 Precision:0.81 Recall:0.88
# 192896
# 42/88 Chopin_op38_p20: F-score:0.80 Precision:0.76 Recall:0.84
# 192896
# 43/88 Chopin_op38_p21: F-score:0.74 Precision:0.70 Recall:0.79
# 192896
# 44/88 Chopin_op38_p22: F-score:0.79 Precision:0.74 Recall:0.84
# 151360
# 45/88 Mozart_K331_1st-mov_p01: F-score:0.86 Precision:0.83 Recall:0.90
# 151360
# 46/88 Mozart_K331_1st-mov_p02: F-score:0.90 Precision:0.87 Recall:0.92
# 151360
# 47/88 Mozart_K331_1st-mov_p03: F-score:0.38 Precision:0.33 Recall:0.45
# 151360
# 48/88 Mozart_K331_1st-mov_p04: F-score:0.88 Precision:0.86 Recall:0.91
# 151360
# 49/88 Mozart_K331_1st-mov_p05: F-score:0.70 Precision:0.66 Recall:0.76
# 151360
# 50/88 Mozart_K331_1st-mov_p06: F-score:0.61 Precision:0.56 Recall:0.67
# 151360
# 51/88 Mozart_K331_1st-mov_p07: F-score:0.46 Precision:0.41 Recall:0.52
# 151360
# 52/88 Mozart_K331_1st-mov_p08: F-score:0.86 Precision:0.83 Recall:0.90
# 151360
# 53/88 Mozart_K331_1st-mov_p09: F-score:0.53 Precision:0.47 Recall:0.59
# 151360
# 54/88 Mozart_K331_1st-mov_p10: F-score:0.80 Precision:0.75 Recall:0.85
# 151360
# 55/88 Mozart_K331_1st-mov_p11: F-score:0.94 Precision:0.93 Recall:0.95
# 151360
# 56/88 Mozart_K331_1st-mov_p12: F-score:0.89 Precision:0.87 Recall:0.92
# 151360
# 57/88 Mozart_K331_1st-mov_p13: F-score:0.86 Precision:0.83 Recall:0.89
# 151360
# 58/88 Mozart_K331_1st-mov_p14: F-score:0.83 Precision:0.80 Recall:0.86
# 151360
# 59/88 Mozart_K331_1st-mov_p15: F-score:0.92 Precision:0.90 Recall:0.93
# 151360
# 60/88 Mozart_K331_1st-mov_p16: F-score:0.91 Precision:0.89 Recall:0.93
# 151360
# 61/88 Mozart_K331_1st-mov_p17: F-score:0.78 Precision:0.74 Recall:0.83
# 151360
# 62/88 Mozart_K331_1st-mov_p18: F-score:0.58 Precision:0.53 Recall:0.64
# 151360
# 63/88 Mozart_K331_1st-mov_p19: F-score:0.93 Precision:0.90 Recall:0.95
# 151360
# 64/88 Mozart_K331_1st-mov_p20: F-score:0.94 Precision:0.93 Recall:0.96
# 151360
# 65/88 Mozart_K331_1st-mov_p21: F-score:0.35 Precision:0.31 Recall:0.41
# 151360
# 66/88 Mozart_K331_1st-mov_p22: F-score:0.42 Precision:0.37 Recall:0.48
# 67584
# 67/88 Schubert_D783_no15_p01: F-score:0.68 Precision:0.62 Recall:0.76
# 67584
# 68/88 Schubert_D783_no15_p02: F-score:0.71 Precision:0.65 Recall:0.78
# 67584
# 69/88 Schubert_D783_no15_p03: F-score:0.72 Precision:0.66 Recall:0.79
# 67584
# 70/88 Schubert_D783_no15_p04: F-score:0.71 Precision:0.65 Recall:0.78
# 67584
# 71/88 Schubert_D783_no15_p05: F-score:0.77 Precision:0.72 Recall:0.83
# 67584
# 72/88 Schubert_D783_no15_p06: F-score:0.69 Precision:0.63 Recall:0.77
# 67584
# 73/88 Schubert_D783_no15_p07: F-score:0.68 Precision:0.62 Recall:0.75
# 67584
# 74/88 Schubert_D783_no15_p08: F-score:0.72 Precision:0.67 Recall:0.79
# 67584
# 75/88 Schubert_D783_no15_p09: F-score:0.79 Precision:0.74 Recall:0.84
# 67584
# 76/88 Schubert_D783_no15_p10: F-score:0.69 Precision:0.63 Recall:0.77
# 67584
# 77/88 Schubert_D783_no15_p11: F-score:0.77 Precision:0.73 Recall:0.81
# 67584
# 78/88 Schubert_D783_no15_p12: F-score:0.65 Precision:0.59 Recall:0.73
# 67584
# 79/88 Schubert_D783_no15_p13: F-score:0.74 Precision:0.69 Recall:0.80
# 67584
# 80/88 Schubert_D783_no15_p14: F-score:0.78 Precision:0.74 Recall:0.83
# 67584
# 81/88 Schubert_D783_no15_p15: F-score:0.89 Precision:0.86 Recall:0.92
# 67584
# 82/88 Schubert_D783_no15_p16: F-score:0.76 Precision:0.71 Recall:0.83
# 67584
# 83/88 Schubert_D783_no15_p17: F-score:0.81 Precision:0.77 Recall:0.86
# 67584
# 84/88 Schubert_D783_no15_p18: F-score:0.68 Precision:0.62 Recall:0.75
# 67584
# 85/88 Schubert_D783_no15_p19: F-score:0.86 Precision:0.83 Recall:0.90
# 67584
# 86/88 Schubert_D783_no15_p20: F-score:0.78 Precision:0.73 Recall:0.84
# 67584
# 87/88 Schubert_D783_no15_p21: F-score:0.82 Precision:0.77 Recall:0.87
# 67584
# 88/88 Schubert_D783_no15_p22: F-score:0.70 Precision:0.65 Recall:0.77
#
#
# Average Performance over the dataset
# F-score:0.78	Precision:0.74	 Recall:0.82

# %%
# 1. Load the data
dataset = load_dataset('../../test set')
alignments = []
piece_names = []
for i, (piece_name, pdata) in enumerate(dataset.items()):
    print('hello')
    piece_names.append(piece_name)
    performance_note_array, score_note_array, gt_alignment = pdata
    
    score_features, score_idx = compute_pianoroll_score(
        score_note_array=score_note_array,
        time_div="auto",
    )

    performance_features, performance_idx = compute_pianoroll_performance(
        performance_note_array=performance_note_array,
        time_div="auto",
    )
    print('features')
    # 3. Compute the alignment (Adapt this part as needed!)
    warping_path, _ = fast_dynamic_time_warping(
        X=score_features,
        Y=performance_features,
        metric="euclidean",
    )
    print('warped')
    predicted_alignment = greedy_note_alignment(
        warping_path=warping_path,
        idx1=score_idx,
        note_array1=score_note_array,
        idx2=performance_idx,
        note_array2=performance_note_array,
    )
    print('predicted')
    # Compute evaluation (Do not change this)
    alignments.append(predicted_alignment)
outfile = os.path.join('', "TeamMilesDavies_challenge.npz")
export_to_challenge(
            alignments=alignments,
            piece_names=piece_names,
            out=outfile,
        )
print('hello end')
# Out:
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello
# features
# warped
# predicted
# hello end

# %%
#visualizations
# Export files to Parangonada
dataset = load_dataset('../../test set')
pdata = dataset['mozart_batik_kv279_1']
performance_note_array, score_note_array, gt_alignment = pdata
data = np.load('TeamMilesDavies_challenge.npz', allow_pickle = True)
print(data.files)
pred_alignment = data['mozart_batik_kv279_1']
for item in pred_alignment:
    print(item)
outdir = "parangonada_files"
if not os.path.exists(outdir):
    os.mkdir(outdir)
pt.save_parangonada_csv(
    alignment=pred_alignment,
    performance_data=performance_note_array,
    score_data=score_note_array,
    outdir="parangonada_files",
)
# Out:
# ['mozart_batik_kv279_1', 'mozart_batik_kv279_2', 'mozart_batik_kv279_3', 'mozart_batik_kv280_1', 'mozart_batik_kv280_2', 'mozart_batik_kv280_3', 'mozart_batik_kv281_1', 'mozart_batik_kv281_2', 'mozart_batik_kv281_3', 'mozart_batik_kv282_1', 'mozart_batik_kv282_2', 'mozart_batik_kv282_3', 'mozart_batik_kv283_1', 'mozart_batik_kv283_2', 'mozart_batik_kv283_3', 'mozart_batik_kv284_1', 'mozart_batik_kv284_2', 'mozart_batik_kv284_3', 'mozart_batik_kv330_1', 'mozart_batik_kv330_2', 'mozart_batik_kv330_3', 'mozart_batik_kv331_1', 'mozart_batik_kv331_2', 'mozart_batik_kv331_3', 'mozart_batik_kv332_1', 'mozart_batik_kv332_2', 'mozart_batik_kv332_3', 'mozart_batik_kv333_1', 'mozart_batik_kv333_2', 'mozart_batik_kv333_3', 'mozart_batik_kv457_1', 'mozart_batik_kv457_2', 'mozart_batik_kv457_3', 'mozart_batik_kv475_1', 'mozart_batik_kv475_2', 'mozart_batik_kv475_3', 'mozart_batik_kv533_1', 'mozart_batik_kv533_2', 'mozart_batik_kv533_3']
# {'label': 'match', 'score_id': 'n3', 'performance_id': '3'}
# {'label': 'match', 'score_id': 'n1', 'performance_id': '1'}
# {'label': 'match', 'score_id': 'n2', 'performance_id': '2'}
# {'label': 'match', 'score_id': 'n4', 'performance_id': '4'}
# {'label': 'match', 'score_id': 'n5', 'performance_id': '5'}
# {'label': 'match', 'score_id': 'n6', 'performance_id': '6'}
# {'label': 'match', 'score_id': 'n7', 'performance_id': '7'}
# {'label': 'match', 'score_id': 'n8', 'performance_id': '8'}
# {'label': 'match', 'score_id': 'n9', 'performance_id': '9'}
# {'label': 'match', 'score_id': 'n10', 'performance_id': '10'}
# {'label': 'match', 'score_id': 'n11', 'performance_id': '11'}
# {'label': 'match', 'score_id': 'n12', 'performance_id': '12'}
# {'label': 'match', 'score_id': 'n13', 'performance_id': '13'}
# {'label': 'match', 'score_id': 'n14', 'performance_id': '14'}
# {'label': 'match', 'score_id': 'n15', 'performance_id': '15'}
# {'label': 'match', 'score_id': 'n16', 'performance_id': '16'}
# {'label': 'match', 'score_id': 'n17', 'performance_id': '17'}
# {'label': 'match', 'score_id': 'n18', 'performance_id': '18'}
# {'label': 'match', 'score_id': 'n21', 'performance_id': '21'}
# {'label': 'match', 'score_id': 'n23', 'performance_id': '23'}
# {'label': 'match', 'score_id': 'n19', 'performance_id': '19'}
# {'label': 'match', 'score_id': 'n20', 'performance_id': '20'}
# {'label': 'match', 'score_id': 'n22', 'performance_id': '22'}
# {'label': 'match', 'score_id': 'n24', 'performance_id': '24'}
# {'label': 'match', 'score_id': 'n25', 'performance_id': '25'}
# {'label': 'match', 'score_id': 'n26', 'performance_id': '26'}
# {'label': 'match', 'score_id': 'n27', 'performance_id': '27'}
# {'label': 'match', 'score_id': 'n28', 'performance_id': '28'}
# {'label': 'match', 'score_id': 'n28', 'performance_id': '30'}
# {'label': 'match', 'score_id': 'n29', 'performance_id': '29'}
# {'label': 'match', 'score_id': 'n29', 'performance_id': '31'}
# {'label': 'match', 'score_id': 'n29', 'performance_id': '34'}
# {'label': 'match', 'score_id': 'n32', 'performance_id': '32'}
# {'label': 'match', 'score_id': 'n33', 'performance_id': '33'}
# {'label': 'deletion', 'score_id': 'n34'}
# {'label': 'match', 'score_id': 'n35', 'performance_id': '35'}
# {'label': 'match', 'score_id': 'n37', 'performance_id': '37'}
# {'label': 'match', 'score_id': 'n36', 'performance_id': '36'}
# {'label': 'match', 'score_id': 'n38', 'performance_id': '38'}
# {'label': 'match', 'score_id': 'n39', 'performance_id': '39'}
# {'label': 'match', 'score_id': 'n40', 'performance_id': '40'}
# {'label': 'match', 'score_id': 'n41', 'performance_id': '41'}
# {'label': 'match', 'score_id': 'n43', 'performance_id': '43'}
# {'label': 'match', 'score_id': 'n42', 'performance_id': '42'}
# {'label': 'match', 'score_id': 'n44', 'performance_id': '44'}
# {'label': 'match', 'score_id': 'n45', 'performance_id': '45'}
# {'label': 'match', 'score_id': 'n46', 'performance_id': '46'}
# {'label': 'match', 'score_id': 'n47', 'performance_id': '47'}
# {'label': 'match', 'score_id': 'n48', 'performance_id': '48'}
# {'label': 'match', 'score_id': 'n49', 'performance_id': '49'}
# {'label': 'match', 'score_id': 'n51', 'performance_id': '51'}
# {'label': 'match', 'score_id': 'n52', 'performance_id': '52'}
# {'label': 'match', 'score_id': 'n53', 'performance_id': '53'}
# {'label': 'match', 'score_id': 'n54', 'performance_id': '54'}
# {'label': 'match', 'score_id': 'n55', 'performance_id': '55'}
# {'label': 'match', 'score_id': 'n56', 'performance_id': '56'}
# {'label': 'match', 'score_id': 'n57', 'performance_id': '57'}
# {'label': 'match', 'score_id': 'n58', 'performance_id': '58'}
# {'label': 'match', 'score_id': 'n59', 'performance_id': '59'}
# {'label': 'match', 'score_id': 'n60', 'performance_id': '60'}
# {'label': 'match', 'score_id': 'n60', 'performance_id': '63'}
# {'label': 'match', 'score_id': 'n65', 'performance_id': '65'}
# {'label': 'match', 'score_id': 'n66', 'performance_id': '66'}
# {'label': 'deletion', 'score_id': 'n61'}
# {'label': 'match', 'score_id': 'n62', 'performance_id': '62'}
# {'label': 'deletion', 'score_id': 'n63'}
# {'label': 'match', 'score_id': 'n64', 'performance_id': '64'}
# {'label': 'match', 'score_id': 'n67', 'performance_id': '67'}
# {'label': 'match', 'score_id': 'n68', 'performance_id': '68'}
# {'label': 'match', 'score_id': 'n69', 'performance_id': '69'}
# {'label': 'match', 'score_id': 'n70', 'performance_id': '70'}
# {'label': 'match', 'score_id': 'n70', 'performance_id': '72'}
# {'label': 'match', 'score_id': 'n71', 'performance_id': '71'}
# {'label': 'match', 'score_id': 'n71', 'performance_id': '73'}
# {'label': 'match', 'score_id': 'n74', 'performance_id': '74'}
# {'label': 'match', 'score_id': 'n76', 'performance_id': '76'}
# {'label': 'match', 'score_id': 'n75', 'performance_id': '75'}
# {'label': 'match', 'score_id': 'n77', 'performance_id': '77'}
# {'label': 'match', 'score_id': 'n79', 'performance_id': '79'}
# {'label': 'match', 'score_id': 'n78', 'performance_id': '78'}
# {'label': 'match', 'score_id': 'n80', 'performance_id': '80'}
# {'label': 'match', 'score_id': 'n82', 'performance_id': '82'}
# {'label': 'match', 'score_id': 'n81', 'performance_id': '81'}
# {'label': 'match', 'score_id': 'n83', 'performance_id': '83'}
# {'label': 'match', 'score_id': 'n84', 'performance_id': '84'}
# {'label': 'match', 'score_id': 'n85', 'performance_id': '85'}
# {'label': 'match', 'score_id': 'n86', 'performance_id': '86'}
# {'label': 'match', 'score_id': 'n87', 'performance_id': '87'}
# {'label': 'match', 'score_id': 'n89', 'performance_id': '89'}
# {'label': 'match', 'score_id': 'n88', 'performance_id': '88'}
# {'label': 'match', 'score_id': 'n90', 'performance_id': '90'}
# {'label': 'deletion', 'score_id': 'n91'}
# {'label': 'deletion', 'score_id': 'n93'}
# {'label': 'match', 'score_id': 'n92', 'performance_id': '92'}
# {'label': 'deletion', 'score_id': 'n94'}
# {'label': 'match', 'score_id': 'n96', 'performance_id': '96'}
# {'label': 'match', 'score_id': 'n95', 'performance_id': '95'}
# {'label': 'match', 'score_id': 'n97', 'performance_id': '94'}
# {'label': 'match', 'score_id': 'n97', 'performance_id': '97'}
# {'label': 'match', 'score_id': 'n99', 'performance_id': '99'}
# {'label': 'match', 'score_id': 'n98', 'performance_id': '98'}
# {'label': 'match', 'score_id': 'n100', 'performance_id': '100'}
# {'label': 'match', 'score_id': 'n101', 'performance_id': '101'}
# {'label': 'match', 'score_id': 'n102', 'performance_id': '102'}
# {'label': 'match', 'score_id': 'n104', 'performance_id': '104'}
# {'label': 'match', 'score_id': 'n103', 'performance_id': '103'}
# {'label': 'match', 'score_id': 'n105', 'performance_id': '105'}
# {'label': 'match', 'score_id': 'n106', 'performance_id': '106'}
# {'label': 'match', 'score_id': 'n107', 'performance_id': '107'}
# {'label': 'deletion', 'score_id': 'n108'}
# {'label': 'match', 'score_id': 'n109', 'performance_id': '109'}
# {'label': 'match', 'score_id': 'n111', 'performance_id': '111'}
# {'label': 'match', 'score_id': 'n112', 'performance_id': '112'}
# {'label': 'match', 'score_id': 'n110', 'performance_id': '110'}
# {'label': 'match', 'score_id': 'n114', 'performance_id': '114'}
# {'label': 'match', 'score_id': 'n113', 'performance_id': '113'}
# {'label': 'match', 'score_id': 'n116', 'performance_id': '116'}
# {'label': 'match', 'score_id': 'n115', 'performance_id': '115'}
# {'label': 'match', 'score_id': 'n117', 'performance_id': '117'}
# {'label': 'match', 'score_id': 'n119', 'performance_id': '119'}
# {'label': 'match', 'score_id': 'n118', 'performance_id': '118'}
# {'label': 'match', 'score_id': 'n120', 'performance_id': '120'}
# {'label': 'match', 'score_id': 'n122', 'performance_id': '122'}
# {'label': 'match', 'score_id': 'n121', 'performance_id': '121'}
# {'label': 'match', 'score_id': 'n123', 'performance_id': '123'}
# {'label': 'match', 'score_id': 'n124', 'performance_id': '124'}
# {'label': 'match', 'score_id': 'n125', 'performance_id': '125'}
# {'label': 'match', 'score_id': 'n127', 'performance_id': '127'}
# {'label': 'match', 'score_id': 'n126', 'performance_id': '126'}
# {'label': 'match', 'score_id': 'n128', 'performance_id': '128'}
# {'label': 'match', 'score_id': 'n129', 'performance_id': '129'}
# {'label': 'match', 'score_id': 'n130', 'performance_id': '130'}
# {'label': 'match', 'score_id': 'n131', 'performance_id': '131'}
# {'label': 'match', 'score_id': 'n132', 'performance_id': '132'}
# {'label': 'match', 'score_id': 'n134', 'performance_id': '134'}
# {'label': 'match', 'score_id': 'n135', 'performance_id': '133'}
# {'label': 'match', 'score_id': 'n135', 'performance_id': '135'}
# {'label': 'match', 'score_id': 'n135', 'performance_id': '138'}
# {'label': 'match', 'score_id': 'n136', 'performance_id': '136'}
# {'label': 'match', 'score_id': 'n139', 'performance_id': '139'}
# {'label': 'match', 'score_id': 'n140', 'performance_id': '140'}
# {'label': 'match', 'score_id': 'n141', 'performance_id': '141'}
# {'label': 'match', 'score_id': 'n142', 'performance_id': '142'}
# {'label': 'match', 'score_id': 'n143', 'performance_id': '143'}
# {'label': 'match', 'score_id': 'n144', 'performance_id': '144'}
# {'label': 'match', 'score_id': 'n146', 'performance_id': '146'}
# {'label': 'match', 'score_id': 'n145', 'performance_id': '145'}
# {'label': 'match', 'score_id': 'n147', 'performance_id': '147'}
# {'label': 'match', 'score_id': 'n148', 'performance_id': '148'}
# {'label': 'match', 'score_id': 'n149', 'performance_id': '149'}
# {'label': 'match', 'score_id': 'n151', 'performance_id': '151'}
# {'label': 'match', 'score_id': 'n150', 'performance_id': '150'}
# {'label': 'match', 'score_id': 'n152', 'performance_id': '152'}
# {'label': 'match', 'score_id': 'n153', 'performance_id': '153'}
# {'label': 'match', 'score_id': 'n154', 'performance_id': '154'}
# {'label': 'match', 'score_id': 'n156', 'performance_id': '156'}
# {'label': 'match', 'score_id': 'n155', 'performance_id': '155'}
# {'label': 'match', 'score_id': 'n157', 'performance_id': '157'}
# {'label': 'match', 'score_id': 'n159', 'performance_id': '159'}
# {'label': 'match', 'score_id': 'n158', 'performance_id': '158'}
# {'label': 'match', 'score_id': 'n160', 'performance_id': '160'}
# {'label': 'match', 'score_id': 'n161', 'performance_id': '161'}
# {'label': 'match', 'score_id': 'n163', 'performance_id': '163'}
# {'label': 'match', 'score_id': 'n162', 'performance_id': '162'}
# {'label': 'match', 'score_id': 'n165', 'performance_id': '165'}
# {'label': 'match', 'score_id': 'n164', 'performance_id': '164'}
# {'label': 'match', 'score_id': 'n167', 'performance_id': '167'}
# {'label': 'match', 'score_id': 'n166', 'performance_id': '166'}
# {'label': 'match', 'score_id': 'n169', 'performance_id': '169'}
# {'label': 'match', 'score_id': 'n168', 'performance_id': '168'}
# {'label': 'match', 'score_id': 'n171', 'performance_id': '171'}
# {'label': 'match', 'score_id': 'n170', 'performance_id': '170'}
# {'label': 'match', 'score_id': 'n172', 'performance_id': '172'}
# {'label': 'match', 'score_id': 'n173', 'performance_id': '173'}
# {'label': 'match', 'score_id': 'n174', 'performance_id': '174'}
# {'label': 'match', 'score_id': 'n176', 'performance_id': '176'}
# {'label': 'match', 'score_id': 'n175', 'performance_id': '175'}
# {'label': 'match', 'score_id': 'n177', 'performance_id': '177'}
# {'label': 'match', 'score_id': 'n178', 'performance_id': '178'}
# {'label': 'match', 'score_id': 'n179', 'performance_id': '179'}
# {'label': 'match', 'score_id': 'n180', 'performance_id': '180'}
# {'label': 'match', 'score_id': 'n181', 'performance_id': '181'}
# {'label': 'match', 'score_id': 'n182', 'performance_id': '182'}
# {'label': 'match', 'score_id': 'n183', 'performance_id': '183'}
# {'label': 'match', 'score_id': 'n184', 'performance_id': '184'}
# {'label': 'match', 'score_id': 'n185', 'performance_id': '185'}
# {'label': 'match', 'score_id': 'n186', 'performance_id': '186'}
# {'label': 'match', 'score_id': 'n187', 'performance_id': '187'}
# {'label': 'match', 'score_id': 'n188', 'performance_id': '188'}
# {'label': 'match', 'score_id': 'n189', 'performance_id': '189'}
# {'label': 'match', 'score_id': 'n190', 'performance_id': '190'}
# {'label': 'match', 'score_id': 'n191', 'performance_id': '191'}
# {'label': 'match', 'score_id': 'n192', 'performance_id': '192'}
# {'label': 'match', 'score_id': 'n193', 'performance_id': '193'}
# {'label': 'match', 'score_id': 'n194', 'performance_id': '194'}
# {'label': 'match', 'score_id': 'n195', 'performance_id': '195'}
# {'label': 'match', 'score_id': 'n195', 'performance_id': '196'}
# {'label': 'deletion', 'score_id': 'n196'}
# {'label': 'match', 'score_id': 'n197', 'performance_id': '197'}
# {'label': 'match', 'score_id': 'n199', 'performance_id': '199'}
# {'label': 'match', 'score_id': 'n198', 'performance_id': '198'}
# {'label': 'match', 'score_id': 'n200', 'performance_id': '200'}
# {'label': 'match', 'score_id': 'n201', 'performance_id': '201'}
# {'label': 'match', 'score_id': 'n201', 'performance_id': '203'}
# {'label': 'match', 'score_id': 'n204', 'performance_id': '204'}
# {'label': 'match', 'score_id': 'n204', 'performance_id': '207'}
# {'label': 'match', 'score_id': 'n202', 'performance_id': '202'}
# {'label': 'deletion', 'score_id': 'n203'}
# {'label': 'match', 'score_id': 'n205', 'performance_id': '205'}
# {'label': 'deletion', 'score_id': 'n207'}
# {'label': 'match', 'score_id': 'n208', 'performance_id': '208'}
# {'label': 'match', 'score_id': 'n208', 'performance_id': '211'}
# {'label': 'match', 'score_id': 'n206', 'performance_id': '206'}
# {'label': 'match', 'score_id': 'n209', 'performance_id': '209'}
# {'label': 'match', 'score_id': 'n209', 'performance_id': '210'}
# {'label': 'match', 'score_id': 'n212', 'performance_id': '212'}
# {'label': 'deletion', 'score_id': 'n211'}
# {'label': 'deletion', 'score_id': 'n210'}
# {'label': 'match', 'score_id': 'n215', 'performance_id': '215'}
# {'label': 'match', 'score_id': 'n214', 'performance_id': '214'}
# {'label': 'match', 'score_id': 'n213', 'performance_id': '213'}
# {'label': 'match', 'score_id': 'n216', 'performance_id': '216'}
# {'label': 'match', 'score_id': 'n217', 'performance_id': '217'}
# {'label': 'match', 'score_id': 'n218', 'performance_id': '218'}
# {'label': 'match', 'score_id': 'n219', 'performance_id': '219'}
# {'label': 'match', 'score_id': 'n220', 'performance_id': '220'}
# {'label': 'match', 'score_id': 'n221', 'performance_id': '221'}
# {'label': 'match', 'score_id': 'n222', 'performance_id': '222'}
# {'label': 'match', 'score_id': 'n223', 'performance_id': '223'}
# {'label': 'match', 'score_id': 'n224', 'performance_id': '224'}
# {'label': 'match', 'score_id': 'n225', 'performance_id': '225'}
# {'label': 'match', 'score_id': 'n226', 'performance_id': '226'}
# {'label': 'match', 'score_id': 'n227', 'performance_id': '227'}
# {'label': 'match', 'score_id': 'n228', 'performance_id': '228'}
# {'label': 'match', 'score_id': 'n229', 'performance_id': '229'}
# {'label': 'match', 'score_id': 'n230', 'performance_id': '230'}
# {'label': 'match', 'score_id': 'n231', 'performance_id': '231'}
# {'label': 'match', 'score_id': 'n231', 'performance_id': '232'}
# {'label': 'deletion', 'score_id': 'n232'}
# {'label': 'match', 'score_id': 'n233', 'performance_id': '233'}
# {'label': 'match', 'score_id': 'n236', 'performance_id': '236'}
# {'label': 'match', 'score_id': 'n236', 'performance_id': '240'}
# {'label': 'match', 'score_id': 'n235', 'performance_id': '235'}
# {'label': 'match', 'score_id': 'n234', 'performance_id': '234'}
# {'label': 'match', 'score_id': 'n237', 'performance_id': '237'}
# {'label': 'match', 'score_id': 'n237', 'performance_id': '238'}
# {'label': 'match', 'score_id': 'n240', 'performance_id': '243'}
# {'label': 'match', 'score_id': 'n239', 'performance_id': '239'}
# {'label': 'deletion', 'score_id': 'n238'}
# {'label': 'match', 'score_id': 'n241', 'performance_id': '241'}
# {'label': 'deletion', 'score_id': 'n243'}
# {'label': 'match', 'score_id': 'n244', 'performance_id': '244'}
# {'label': 'match', 'score_id': 'n242', 'performance_id': '242'}
# {'label': 'match', 'score_id': 'n245', 'performance_id': '245'}
# {'label': 'match', 'score_id': 'n247', 'performance_id': '247'}
# {'label': 'match', 'score_id': 'n247', 'performance_id': '249'}
# {'label': 'match', 'score_id': 'n246', 'performance_id': '246'}
# {'label': 'match', 'score_id': 'n248', 'performance_id': '248'}
# {'label': 'deletion', 'score_id': 'n249'}
# {'label': 'match', 'score_id': 'n250', 'performance_id': '250'}
# {'label': 'match', 'score_id': 'n251', 'performance_id': '251'}
# {'label': 'match', 'score_id': 'n253', 'performance_id': '253'}
# {'label': 'match', 'score_id': 'n255', 'performance_id': '255'}
# {'label': 'match', 'score_id': 'n254', 'performance_id': '254'}
# {'label': 'match', 'score_id': 'n252', 'performance_id': '252'}
# {'label': 'match', 'score_id': 'n256', 'performance_id': '256'}
# {'label': 'match', 'score_id': 'n257', 'performance_id': '257'}
# {'label': 'match', 'score_id': 'n258', 'performance_id': '258'}
# {'label': 'match', 'score_id': 'n259', 'performance_id': '259'}
# {'label': 'match', 'score_id': 'n261', 'performance_id': '261'}
# {'label': 'match', 'score_id': 'n261', 'performance_id': '263'}
# {'label': 'match', 'score_id': 'n260', 'performance_id': '260'}
# {'label': 'match', 'score_id': 'n262', 'performance_id': '262'}
# {'label': 'deletion', 'score_id': 'n263'}
# {'label': 'match', 'score_id': 'n265', 'performance_id': '265'}
# {'label': 'match', 'score_id': 'n264', 'performance_id': '264'}
# {'label': 'match', 'score_id': 'n264', 'performance_id': '267'}
# {'label': 'match', 'score_id': 'n264', 'performance_id': '269'}
# {'label': 'match', 'score_id': 'n270', 'performance_id': '270'}
# {'label': 'match', 'score_id': 'n272', 'performance_id': '272'}
# {'label': 'match', 'score_id': 'n271', 'performance_id': '271'}
# {'label': 'match', 'score_id': 'n273', 'performance_id': '273'}
# {'label': 'match', 'score_id': 'n274', 'performance_id': '274'}
# {'label': 'match', 'score_id': 'n275', 'performance_id': '275'}
# {'label': 'match', 'score_id': 'n277', 'performance_id': '277'}
# {'label': 'match', 'score_id': 'n279', 'performance_id': '279'}
# {'label': 'match', 'score_id': 'n278', 'performance_id': '278'}
# {'label': 'match', 'score_id': 'n276', 'performance_id': '276'}
# {'label': 'match', 'score_id': 'n280', 'performance_id': '280'}
# {'label': 'match', 'score_id': 'n280', 'performance_id': '281'}
# {'label': 'match', 'score_id': 'n282', 'performance_id': '282'}
# {'label': 'match', 'score_id': 'n283', 'performance_id': '283'}
# {'label': 'match', 'score_id': 'n284', 'performance_id': '284'}
# {'label': 'match', 'score_id': 'n286', 'performance_id': '286'}
# {'label': 'match', 'score_id': 'n286', 'performance_id': '287'}
# {'label': 'match', 'score_id': 'n285', 'performance_id': '285'}
# {'label': 'match', 'score_id': 'n288', 'performance_id': '288'}
# {'label': 'deletion', 'score_id': 'n287'}
# {'label': 'match', 'score_id': 'n290', 'performance_id': '290'}
# {'label': 'match', 'score_id': 'n289', 'performance_id': '289'}
# {'label': 'match', 'score_id': 'n289', 'performance_id': '292'}
# {'label': 'match', 'score_id': 'n294', 'performance_id': '294'}
# {'label': 'match', 'score_id': 'n293', 'performance_id': '291'}
# {'label': 'match', 'score_id': 'n293', 'performance_id': '293'}
# {'label': 'match', 'score_id': 'n293', 'performance_id': '296'}
# {'label': 'match', 'score_id': 'n297', 'performance_id': '297'}
# {'label': 'match', 'score_id': 'n298', 'performance_id': '298'}
# {'label': 'match', 'score_id': 'n299', 'performance_id': '299'}
# {'label': 'match', 'score_id': 'n300', 'performance_id': '300'}
# {'label': 'match', 'score_id': 'n302', 'performance_id': '302'}
# {'label': 'match', 'score_id': 'n301', 'performance_id': '301'}
# {'label': 'match', 'score_id': 'n305', 'performance_id': '305'}
# {'label': 'match', 'score_id': 'n306', 'performance_id': '306'}
# {'label': 'match', 'score_id': 'n307', 'performance_id': '304'}
# {'label': 'match', 'score_id': 'n307', 'performance_id': '307'}
# {'label': 'match', 'score_id': 'n308', 'performance_id': '308'}
# {'label': 'match', 'score_id': 'n308', 'performance_id': '311'}
# {'label': 'match', 'score_id': 'n310', 'performance_id': '310'}
# {'label': 'match', 'score_id': 'n309', 'performance_id': '312'}
# {'label': 'match', 'score_id': 'n313', 'performance_id': '313'}
# {'label': 'match', 'score_id': 'n314', 'performance_id': '314'}
# {'label': 'match', 'score_id': 'n315', 'performance_id': '315'}
# {'label': 'match', 'score_id': 'n316', 'performance_id': '316'}
# {'label': 'match', 'score_id': 'n316', 'performance_id': '319'}
# {'label': 'match', 'score_id': 'n318', 'performance_id': '318'}
# {'label': 'match', 'score_id': 'n317', 'performance_id': '317'}
# {'label': 'match', 'score_id': 'n317', 'performance_id': '320'}
# {'label': 'match', 'score_id': 'n321', 'performance_id': '321'}
# {'label': 'match', 'score_id': 'n322', 'performance_id': '322'}
# {'label': 'match', 'score_id': 'n323', 'performance_id': '323'}
# {'label': 'match', 'score_id': 'n324', 'performance_id': '324'}
# {'label': 'match', 'score_id': 'n325', 'performance_id': '325'}
# {'label': 'match', 'score_id': 'n326', 'performance_id': '326'}
# {'label': 'match', 'score_id': 'n327', 'performance_id': '327'}
# {'label': 'match', 'score_id': 'n328', 'performance_id': '328'}
# {'label': 'match', 'score_id': 'n329', 'performance_id': '329'}
# {'label': 'match', 'score_id': 'n330', 'performance_id': '330'}
# {'label': 'match', 'score_id': 'n331', 'performance_id': '331'}
# {'label': 'match', 'score_id': 'n334', 'performance_id': '334'}
# {'label': 'match', 'score_id': 'n332', 'performance_id': '332'}
# {'label': 'match', 'score_id': 'n333', 'performance_id': '333'}
# {'label': 'match', 'score_id': 'n335', 'performance_id': '335'}
# {'label': 'match', 'score_id': 'n337', 'performance_id': '337'}
# {'label': 'match', 'score_id': 'n338', 'performance_id': '338'}
# {'label': 'match', 'score_id': 'n336', 'performance_id': '336'}
# {'label': 'match', 'score_id': 'n336', 'performance_id': '340'}
# {'label': 'match', 'score_id': 'n341', 'performance_id': '341'}
# {'label': 'match', 'score_id': 'n342', 'performance_id': '342'}
# {'label': 'match', 'score_id': 'n343', 'performance_id': '343'}
# {'label': 'match', 'score_id': 'n344', 'performance_id': '344'}
# {'label': 'match', 'score_id': 'n344', 'performance_id': '346'}
# {'label': 'match', 'score_id': 'n345', 'performance_id': '345'}
# {'label': 'match', 'score_id': 'n346', 'performance_id': '348'}
# {'label': 'match', 'score_id': 'n347', 'performance_id': '347'}
# {'label': 'deletion', 'score_id': 'n348'}
# {'label': 'match', 'score_id': 'n349', 'performance_id': '349'}
# {'label': 'match', 'score_id': 'n350', 'performance_id': '350'}
# {'label': 'match', 'score_id': 'n351', 'performance_id': '351'}
# {'label': 'match', 'score_id': 'n352', 'performance_id': '352'}
# {'label': 'match', 'score_id': 'n353', 'performance_id': '353'}
# {'label': 'match', 'score_id': 'n354', 'performance_id': '354'}
# {'label': 'match', 'score_id': 'n355', 'performance_id': '355'}
# {'label': 'match', 'score_id': 'n356', 'performance_id': '356'}
# {'label': 'match', 'score_id': 'n357', 'performance_id': '357'}
# {'label': 'match', 'score_id': 'n358', 'performance_id': '358'}
# {'label': 'match', 'score_id': 'n359', 'performance_id': '359'}
# {'label': 'match', 'score_id': 'n360', 'performance_id': '360'}
# {'label': 'match', 'score_id': 'n361', 'performance_id': '361'}
# {'label': 'match', 'score_id': 'n362', 'performance_id': '362'}
# {'label': 'match', 'score_id': 'n363', 'performance_id': '363'}
# {'label': 'match', 'score_id': 'n366', 'performance_id': '366'}
# {'label': 'match', 'score_id': 'n365', 'performance_id': '365'}
# {'label': 'match', 'score_id': 'n364', 'performance_id': '364'}
# {'label': 'match', 'score_id': 'n367', 'performance_id': '367'}
# {'label': 'match', 'score_id': 'n370', 'performance_id': '370'}
# {'label': 'match', 'score_id': 'n369', 'performance_id': '369'}
# {'label': 'match', 'score_id': 'n368', 'performance_id': '368'}
# {'label': 'match', 'score_id': 'n371', 'performance_id': '371'}
# {'label': 'match', 'score_id': 'n372', 'performance_id': '372'}
# {'label': 'match', 'score_id': 'n373', 'performance_id': '373'}
# {'label': 'match', 'score_id': 'n374', 'performance_id': '374'}
# {'label': 'match', 'score_id': 'n375', 'performance_id': '375'}
# {'label': 'match', 'score_id': 'n376', 'performance_id': '376'}
# {'label': 'match', 'score_id': 'n377', 'performance_id': '377'}
# {'label': 'match', 'score_id': 'n377', 'performance_id': '379'}
# {'label': 'match', 'score_id': 'n378', 'performance_id': '378'}
# {'label': 'deletion', 'score_id': 'n379'}
# {'label': 'deletion', 'score_id': 'n380'}
# {'label': 'match', 'score_id': 'n381', 'performance_id': '381'}
# {'label': 'match', 'score_id': 'n381', 'performance_id': '383'}
# {'label': 'match', 'score_id': 'n382', 'performance_id': '382'}
# {'label': 'deletion', 'score_id': 'n383'}
# {'label': 'match', 'score_id': 'n384', 'performance_id': '384'}
# {'label': 'match', 'score_id': 'n385', 'performance_id': '385'}
# {'label': 'match', 'score_id': 'n386', 'performance_id': '386'}
# {'label': 'match', 'score_id': 'n387', 'performance_id': '387'}
# {'label': 'match', 'score_id': 'n388', 'performance_id': '388'}
# {'label': 'match', 'score_id': 'n389', 'performance_id': '389'}
# {'label': 'match', 'score_id': 'n390', 'performance_id': '390'}
# {'label': 'match', 'score_id': 'n391', 'performance_id': '391'}
# {'label': 'match', 'score_id': 'n392', 'performance_id': '392'}
# {'label': 'match', 'score_id': 'n393', 'performance_id': '393'}
# {'label': 'match', 'score_id': 'n394', 'performance_id': '394'}
# {'label': 'match', 'score_id': 'n395', 'performance_id': '395'}
# {'label': 'match', 'score_id': 'n396', 'performance_id': '396'}
# {'label': 'match', 'score_id': 'n397', 'performance_id': '397'}
# {'label': 'match', 'score_id': 'n398', 'performance_id': '398'}
# {'label': 'match', 'score_id': 'n401', 'performance_id': '401'}
# {'label': 'match', 'score_id': 'n400', 'performance_id': '400'}
# {'label': 'match', 'score_id': 'n399', 'performance_id': '399'}
# {'label': 'match', 'score_id': 'n402', 'performance_id': '402'}
# {'label': 'match', 'score_id': 'n404', 'performance_id': '404'}
# {'label': 'match', 'score_id': 'n403', 'performance_id': '403'}
# {'label': 'match', 'score_id': 'n405', 'performance_id': '405'}
# {'label': 'match', 'score_id': 'n406', 'performance_id': '406'}
# {'label': 'match', 'score_id': 'n407', 'performance_id': '407'}
# {'label': 'match', 'score_id': 'n408', 'performance_id': '408'}
# {'label': 'match', 'score_id': 'n409', 'performance_id': '409'}
# {'label': 'match', 'score_id': 'n409', 'performance_id': '411'}
# {'label': 'match', 'score_id': 'n410', 'performance_id': '410'}
# {'label': 'match', 'score_id': 'n412', 'performance_id': '412'}
# {'label': 'deletion', 'score_id': 'n411'}
# {'label': 'match', 'score_id': 'n413', 'performance_id': '413'}
# {'label': 'match', 'score_id': 'n415', 'performance_id': '415'}
# {'label': 'match', 'score_id': 'n414', 'performance_id': '414'}
# {'label': 'match', 'score_id': 'n416', 'performance_id': '416'}
# {'label': 'match', 'score_id': 'n417', 'performance_id': '417'}
# {'label': 'match', 'score_id': 'n418', 'performance_id': '418'}
# {'label': 'match', 'score_id': 'n419', 'performance_id': '419'}
# {'label': 'match', 'score_id': 'n421', 'performance_id': '421'}
# {'label': 'match', 'score_id': 'n420', 'performance_id': '420'}
# {'label': 'match', 'score_id': 'n422', 'performance_id': '422'}
# {'label': 'match', 'score_id': 'n423', 'performance_id': '423'}
# {'label': 'match', 'score_id': 'n425', 'performance_id': '425'}
# {'label': 'match', 'score_id': 'n424', 'performance_id': '424'}
# {'label': 'match', 'score_id': 'n426', 'performance_id': '426'}
# {'label': 'match', 'score_id': 'n427', 'performance_id': '427'}
# {'label': 'match', 'score_id': 'n429', 'performance_id': '429'}
# {'label': 'match', 'score_id': 'n428', 'performance_id': '428'}
# {'label': 'match', 'score_id': 'n430', 'performance_id': '430'}
# {'label': 'match', 'score_id': 'n431', 'performance_id': '431'}
# {'label': 'match', 'score_id': 'n432', 'performance_id': '432'}
# {'label': 'match', 'score_id': 'n433', 'performance_id': '433'}
# {'label': 'match', 'score_id': 'n434', 'performance_id': '434'}
# {'label': 'match', 'score_id': 'n435', 'performance_id': '435'}
# {'label': 'match', 'score_id': 'n436', 'performance_id': '436'}
# {'label': 'match', 'score_id': 'n438', 'performance_id': '438'}
# {'label': 'match', 'score_id': 'n437', 'performance_id': '437'}
# {'label': 'match', 'score_id': 'n440', 'performance_id': '440'}
# {'label': 'match', 'score_id': 'n439', 'performance_id': '439'}
# {'label': 'match', 'score_id': 'n442', 'performance_id': '442'}
# {'label': 'match', 'score_id': 'n441', 'performance_id': '441'}
# {'label': 'match', 'score_id': 'n443', 'performance_id': '443'}
# {'label': 'match', 'score_id': 'n444', 'performance_id': '444'}
# {'label': 'match', 'score_id': 'n446', 'performance_id': '446'}
# {'label': 'match', 'score_id': 'n445', 'performance_id': '445'}
# {'label': 'match', 'score_id': 'n448', 'performance_id': '448'}
# {'label': 'match', 'score_id': 'n447', 'performance_id': '447'}
# {'label': 'match', 'score_id': 'n450', 'performance_id': '450'}
# {'label': 'match', 'score_id': 'n449', 'performance_id': '449'}
# {'label': 'match', 'score_id': 'n452', 'performance_id': '452'}
# {'label': 'match', 'score_id': 'n451', 'performance_id': '451'}
# {'label': 'match', 'score_id': 'n454', 'performance_id': '454'}
# {'label': 'match', 'score_id': 'n453', 'performance_id': '453'}
# {'label': 'match', 'score_id': 'n456', 'performance_id': '456'}
# {'label': 'match', 'score_id': 'n455', 'performance_id': '455'}
# {'label': 'match', 'score_id': 'n457', 'performance_id': '457'}
# {'label': 'match', 'score_id': 'n458', 'performance_id': '458'}
# {'label': 'match', 'score_id': 'n459', 'performance_id': '459'}
# {'label': 'match', 'score_id': 'n460', 'performance_id': '460'}
# {'label': 'match', 'score_id': 'n462', 'performance_id': '462'}
# {'label': 'match', 'score_id': 'n461', 'performance_id': '461'}
# {'label': 'match', 'score_id': 'n463', 'performance_id': '463'}
# {'label': 'match', 'score_id': 'n465', 'performance_id': '465'}
# {'label': 'match', 'score_id': 'n464', 'performance_id': '464'}
# {'label': 'match', 'score_id': 'n464', 'performance_id': '467'}
# {'label': 'match', 'score_id': 'n468', 'performance_id': '468'}
# {'label': 'match', 'score_id': 'n469', 'performance_id': '469'}
# {'label': 'match', 'score_id': 'n470', 'performance_id': '470'}
# {'label': 'match', 'score_id': 'n471', 'performance_id': '471'}
# {'label': 'match', 'score_id': 'n473', 'performance_id': '473'}
# {'label': 'match', 'score_id': 'n472', 'performance_id': '472'}
# {'label': 'match', 'score_id': 'n474', 'performance_id': '474'}
# {'label': 'match', 'score_id': 'n474', 'performance_id': '477'}
# {'label': 'match', 'score_id': 'n476', 'performance_id': '476'}
# {'label': 'match', 'score_id': 'n475', 'performance_id': '478'}
# {'label': 'match', 'score_id': 'n479', 'performance_id': '479'}
# {'label': 'match', 'score_id': 'n480', 'performance_id': '480'}
# {'label': 'match', 'score_id': 'n481', 'performance_id': '481'}
# {'label': 'match', 'score_id': 'n482', 'performance_id': '482'}
# {'label': 'match', 'score_id': 'n484', 'performance_id': '484'}
# {'label': 'match', 'score_id': 'n483', 'performance_id': '483'}
# {'label': 'match', 'score_id': 'n485', 'performance_id': '485'}
# {'label': 'match', 'score_id': 'n485', 'performance_id': '488'}
# {'label': 'match', 'score_id': 'n487', 'performance_id': '487'}
# {'label': 'match', 'score_id': 'n486', 'performance_id': '486'}
# {'label': 'match', 'score_id': 'n486', 'performance_id': '489'}
# {'label': 'match', 'score_id': 'n490', 'performance_id': '490'}
# {'label': 'match', 'score_id': 'n491', 'performance_id': '491'}
# {'label': 'match', 'score_id': 'n492', 'performance_id': '492'}
# {'label': 'match', 'score_id': 'n493', 'performance_id': '493'}
# {'label': 'match', 'score_id': 'n495', 'performance_id': '495'}
# {'label': 'match', 'score_id': 'n494', 'performance_id': '494'}
# {'label': 'match', 'score_id': 'n496', 'performance_id': '496'}
# {'label': 'match', 'score_id': 'n497', 'performance_id': '497'}
# {'label': 'match', 'score_id': 'n498', 'performance_id': '498'}
# {'label': 'match', 'score_id': 'n499', 'performance_id': '499'}
# {'label': 'match', 'score_id': 'n500', 'performance_id': '500'}
# {'label': 'match', 'score_id': 'n501', 'performance_id': '501'}
# {'label': 'match', 'score_id': 'n502', 'performance_id': '502'}
# {'label': 'match', 'score_id': 'n503', 'performance_id': '503'}
# {'label': 'match', 'score_id': 'n505', 'performance_id': '505'}
# {'label': 'match', 'score_id': 'n504', 'performance_id': '504'}
# {'label': 'match', 'score_id': 'n506', 'performance_id': '506'}
# {'label': 'match', 'score_id': 'n506', 'performance_id': '507'}
# {'label': 'match', 'score_id': 'n508', 'performance_id': '508'}
# {'label': 'deletion', 'score_id': 'n507'}
# {'label': 'match', 'score_id': 'n509', 'performance_id': '509'}
# {'label': 'match', 'score_id': 'n510', 'performance_id': '510'}
# {'label': 'match', 'score_id': 'n511', 'performance_id': '511'}
# {'label': 'match', 'score_id': 'n512', 'performance_id': '512'}
# {'label': 'match', 'score_id': 'n513', 'performance_id': '513'}
# {'label': 'match', 'score_id': 'n515', 'performance_id': '515'}
# {'label': 'match', 'score_id': 'n514', 'performance_id': '514'}
# {'label': 'match', 'score_id': 'n516', 'performance_id': '516'}
# {'label': 'match', 'score_id': 'n516', 'performance_id': '517'}
# {'label': 'match', 'score_id': 'n518', 'performance_id': '518'}
# {'label': 'deletion', 'score_id': 'n517'}
# {'label': 'match', 'score_id': 'n519', 'performance_id': '519'}
# {'label': 'match', 'score_id': 'n520', 'performance_id': '520'}
# {'label': 'match', 'score_id': 'n521', 'performance_id': '521'}
# {'label': 'match', 'score_id': 'n522', 'performance_id': '522'}
# {'label': 'match', 'score_id': 'n523', 'performance_id': '523'}
# {'label': 'match', 'score_id': 'n524', 'performance_id': '524'}
# {'label': 'match', 'score_id': 'n525', 'performance_id': '525'}
# {'label': 'match', 'score_id': 'n526', 'performance_id': '526'}
# {'label': 'match', 'score_id': 'n528', 'performance_id': '528'}
# {'label': 'match', 'score_id': 'n527', 'performance_id': '527'}
# {'label': 'match', 'score_id': 'n529', 'performance_id': '529'}
# {'label': 'match', 'score_id': 'n530', 'performance_id': '530'}
# {'label': 'match', 'score_id': 'n531', 'performance_id': '531'}
# {'label': 'match', 'score_id': 'n533', 'performance_id': '533'}
# {'label': 'match', 'score_id': 'n534', 'performance_id': '532'}
# {'label': 'match', 'score_id': 'n534', 'performance_id': '536'}
# {'label': 'match', 'score_id': 'n534', 'performance_id': '539'}
# {'label': 'match', 'score_id': 'n534', 'performance_id': '542'}
# {'label': 'match', 'score_id': 'n535', 'performance_id': '535'}
# {'label': 'match', 'score_id': 'n538', 'performance_id': '538'}
# {'label': 'match', 'score_id': 'n541', 'performance_id': '541'}
# {'label': 'match', 'score_id': 'n538', 'performance_id': '543'}
# {'label': 'match', 'score_id': 'n541', 'performance_id': '544'}
# {'label': 'match', 'score_id': 'n545', 'performance_id': '545'}
# {'label': 'match', 'score_id': 'n546', 'performance_id': '546'}
# {'label': 'match', 'score_id': 'n547', 'performance_id': '547'}
# {'label': 'match', 'score_id': 'n548', 'performance_id': '548'}
# {'label': 'match', 'score_id': 'n549', 'performance_id': '549'}
# {'label': 'match', 'score_id': 'n550', 'performance_id': '550'}
# {'label': 'match', 'score_id': 'n551', 'performance_id': '551'}
# {'label': 'match', 'score_id': 'n552', 'performance_id': '552'}
# {'label': 'match', 'score_id': 'n553', 'performance_id': '553'}
# {'label': 'match', 'score_id': 'n554', 'performance_id': '554'}
# {'label': 'match', 'score_id': 'n556', 'performance_id': '556'}
# {'label': 'match', 'score_id': 'n555', 'performance_id': '555'}
# {'label': 'match', 'score_id': 'n555', 'performance_id': '560'}
# {'label': 'match', 'score_id': 'n557', 'performance_id': '557'}
# {'label': 'match', 'score_id': 'n559', 'performance_id': '559'}
# {'label': 'match', 'score_id': 'n558', 'performance_id': '558'}
# {'label': 'deletion', 'score_id': 'n560'}
# {'label': 'match', 'score_id': 'n561', 'performance_id': '561'}
# {'label': 'match', 'score_id': 'n563', 'performance_id': '563'}
# {'label': 'match', 'score_id': 'n562', 'performance_id': '562'}
# {'label': 'match', 'score_id': 'n562', 'performance_id': '566'}
# {'label': 'match', 'score_id': 'n564', 'performance_id': '564'}
# {'label': 'match', 'score_id': 'n567', 'performance_id': '567'}
# {'label': 'match', 'score_id': 'n565', 'performance_id': '565'}
# {'label': 'match', 'score_id': 'n566', 'performance_id': '569'}
# {'label': 'match', 'score_id': 'n568', 'performance_id': '568'}
# {'label': 'match', 'score_id': 'n570', 'performance_id': '570'}
# {'label': 'deletion', 'score_id': 'n569'}
# {'label': 'match', 'score_id': 'n572', 'performance_id': '572'}
# {'label': 'match', 'score_id': 'n571', 'performance_id': '571'}
# {'label': 'match', 'score_id': 'n574', 'performance_id': '574'}
# {'label': 'match', 'score_id': 'n573', 'performance_id': '573'}
# {'label': 'match', 'score_id': 'n575', 'performance_id': '575'}
# {'label': 'match', 'score_id': 'n576', 'performance_id': '576'}
# {'label': 'match', 'score_id': 'n577', 'performance_id': '577'}
# {'label': 'match', 'score_id': 'n579', 'performance_id': '579'}
# {'label': 'match', 'score_id': 'n578', 'performance_id': '578'}
# {'label': 'match', 'score_id': 'n580', 'performance_id': '580'}
# {'label': 'match', 'score_id': 'n581', 'performance_id': '581'}
# {'label': 'match', 'score_id': 'n582', 'performance_id': '582'}
# {'label': 'match', 'score_id': 'n583', 'performance_id': '583'}
# {'label': 'match', 'score_id': 'n584', 'performance_id': '584'}
# {'label': 'match', 'score_id': 'n585', 'performance_id': '585'}
# {'label': 'match', 'score_id': 'n586', 'performance_id': '586'}
# {'label': 'match', 'score_id': 'n588', 'performance_id': '588'}
# {'label': 'match', 'score_id': 'n587', 'performance_id': '587'}
# {'label': 'match', 'score_id': 'n588', 'performance_id': '589'}
# {'label': 'match', 'score_id': 'n590', 'performance_id': '590'}
# {'label': 'match', 'score_id': 'n592', 'performance_id': '592'}
# {'label': 'match', 'score_id': 'n591', 'performance_id': '591'}
# {'label': 'match', 'score_id': 'n594', 'performance_id': '594'}
# {'label': 'match', 'score_id': 'n594', 'performance_id': '595'}
# {'label': 'match', 'score_id': 'n593', 'performance_id': '593'}
# {'label': 'match', 'score_id': 'n597', 'performance_id': '597'}
# {'label': 'match', 'score_id': 'n596', 'performance_id': '596'}
# {'label': 'match', 'score_id': 'n598', 'performance_id': '598'}
# {'label': 'match', 'score_id': 'n599', 'performance_id': '599'}
# {'label': 'match', 'score_id': 'n601', 'performance_id': '601'}
# {'label': 'match', 'score_id': 'n600', 'performance_id': '600'}
# {'label': 'match', 'score_id': 'n602', 'performance_id': '602'}
# {'label': 'match', 'score_id': 'n603', 'performance_id': '603'}
# {'label': 'match', 'score_id': 'n605', 'performance_id': '605'}
# {'label': 'match', 'score_id': 'n604', 'performance_id': '604'}
# {'label': 'match', 'score_id': 'n606', 'performance_id': '606'}
# {'label': 'match', 'score_id': 'n607', 'performance_id': '607'}
# {'label': 'match', 'score_id': 'n608', 'performance_id': '608'}
# {'label': 'match', 'score_id': 'n609', 'performance_id': '609'}
# {'label': 'match', 'score_id': 'n611', 'performance_id': '611'}
# {'label': 'match', 'score_id': 'n610', 'performance_id': '610'}
# {'label': 'match', 'score_id': 'n613', 'performance_id': '613'}
# {'label': 'match', 'score_id': 'n612', 'performance_id': '612'}
# {'label': 'match', 'score_id': 'n615', 'performance_id': '615'}
# {'label': 'match', 'score_id': 'n614', 'performance_id': '614'}
# {'label': 'match', 'score_id': 'n617', 'performance_id': '617'}
# {'label': 'match', 'score_id': 'n616', 'performance_id': '616'}
# {'label': 'match', 'score_id': 'n618', 'performance_id': '618'}
# {'label': 'match', 'score_id': 'n619', 'performance_id': '619'}
# {'label': 'match', 'score_id': 'n621', 'performance_id': '621'}
# {'label': 'match', 'score_id': 'n620', 'performance_id': '620'}
# {'label': 'match', 'score_id': 'n623', 'performance_id': '623'}
# {'label': 'match', 'score_id': 'n622', 'performance_id': '622'}
# {'label': 'match', 'score_id': 'n624', 'performance_id': '624'}
# {'label': 'match', 'score_id': 'n625', 'performance_id': '625'}
# {'label': 'match', 'score_id': 'n626', 'performance_id': '626'}
# {'label': 'match', 'score_id': 'n626', 'performance_id': '628'}
# {'label': 'match', 'score_id': 'n627', 'performance_id': '627'}
# {'label': 'deletion', 'score_id': 'n628'}
# {'label': 'match', 'score_id': 'n629', 'performance_id': '629'}
# {'label': 'match', 'score_id': 'n630', 'performance_id': '630'}
# {'label': 'match', 'score_id': 'n632', 'performance_id': '632'}
# {'label': 'match', 'score_id': 'n631', 'performance_id': '631'}
# {'label': 'match', 'score_id': 'n634', 'performance_id': '634'}
# {'label': 'match', 'score_id': 'n633', 'performance_id': '633'}
# {'label': 'match', 'score_id': 'n636', 'performance_id': '636'}
# {'label': 'match', 'score_id': 'n635', 'performance_id': '635'}
# {'label': 'match', 'score_id': 'n637', 'performance_id': '637'}
# {'label': 'match', 'score_id': 'n638', 'performance_id': '638'}
# {'label': 'match', 'score_id': 'n638', 'performance_id': '641'}
# {'label': 'match', 'score_id': 'n638', 'performance_id': '645'}
# {'label': 'match', 'score_id': 'n638', 'performance_id': '648'}
# {'label': 'match', 'score_id': 'n638', 'performance_id': '651'}
# {'label': 'match', 'score_id': 'n638', 'performance_id': '654'}
# {'label': 'match', 'score_id': 'n638', 'performance_id': '657'}
# {'label': 'match', 'score_id': 'n640', 'performance_id': '640'}
# {'label': 'deletion', 'score_id': 'n642'}
# {'label': 'match', 'score_id': 'n644', 'performance_id': '644'}
# {'label': 'match', 'score_id': 'n647', 'performance_id': '647'}
# {'label': 'match', 'score_id': 'n649', 'performance_id': '649'}
# {'label': 'match', 'score_id': 'n652', 'performance_id': '652'}
# {'label': 'match', 'score_id': 'n655', 'performance_id': '655'}
# {'label': 'match', 'score_id': 'n658', 'performance_id': '658'}
# {'label': 'match', 'score_id': 'n659', 'performance_id': '656'}
# {'label': 'match', 'score_id': 'n659', 'performance_id': '659'}
# {'label': 'match', 'score_id': 'n660', 'performance_id': '660'}
# {'label': 'match', 'score_id': 'n661', 'performance_id': '661'}
# {'label': 'match', 'score_id': 'n662', 'performance_id': '662'}
# {'label': 'match', 'score_id': 'n662', 'performance_id': '664'}
# {'label': 'match', 'score_id': 'n663', 'performance_id': '663'}
# {'label': 'deletion', 'score_id': 'n664'}
# {'label': 'match', 'score_id': 'n665', 'performance_id': '665'}
# {'label': 'match', 'score_id': 'n666', 'performance_id': '666'}
# {'label': 'match', 'score_id': 'n667', 'performance_id': '667'}
# {'label': 'match', 'score_id': 'n668', 'performance_id': '668'}
# {'label': 'match', 'score_id': 'n669', 'performance_id': '669'}
# {'label': 'match', 'score_id': 'n671', 'performance_id': '671'}
# {'label': 'match', 'score_id': 'n670', 'performance_id': '670'}
# {'label': 'match', 'score_id': 'n672', 'performance_id': '672'}
# {'label': 'match', 'score_id': 'n674', 'performance_id': '674'}
# {'label': 'match', 'score_id': 'n673', 'performance_id': '673'}
# {'label': 'match', 'score_id': 'n673', 'performance_id': '675'}
# {'label': 'match', 'score_id': 'n676', 'performance_id': '676'}
# {'label': 'match', 'score_id': 'n675', 'performance_id': '677'}
# {'label': 'match', 'score_id': 'n678', 'performance_id': '678'}
# {'label': 'deletion', 'score_id': 'n677'}
# {'label': 'match', 'score_id': 'n679', 'performance_id': '679'}
# {'label': 'match', 'score_id': 'n680', 'performance_id': '680'}
# {'label': 'match', 'score_id': 'n681', 'performance_id': '681'}
# {'label': 'match', 'score_id': 'n683', 'performance_id': '683'}
# {'label': 'match', 'score_id': 'n682', 'performance_id': '682'}
# {'label': 'match', 'score_id': 'n684', 'performance_id': '684'}
# {'label': 'match', 'score_id': 'n686', 'performance_id': '686'}
# {'label': 'match', 'score_id': 'n685', 'performance_id': '685'}
# {'label': 'match', 'score_id': 'n685', 'performance_id': '687'}
# {'label': 'match', 'score_id': 'n688', 'performance_id': '688'}
# {'label': 'match', 'score_id': 'n687', 'performance_id': '689'}
# {'label': 'match', 'score_id': 'n690', 'performance_id': '690'}
# {'label': 'deletion', 'score_id': 'n689'}
# {'label': 'match', 'score_id': 'n691', 'performance_id': '691'}
# {'label': 'match', 'score_id': 'n692', 'performance_id': '692'}
# {'label': 'match', 'score_id': 'n693', 'performance_id': '693'}
# {'label': 'match', 'score_id': 'n697', 'performance_id': '697'}
# {'label': 'match', 'score_id': 'n694', 'performance_id': '694'}
# {'label': 'match', 'score_id': 'n696', 'performance_id': '696'}
# {'label': 'match', 'score_id': 'n696', 'performance_id': '702'}
# {'label': 'match', 'score_id': 'n695', 'performance_id': '695'}
# {'label': 'match', 'score_id': 'n698', 'performance_id': '698'}
# {'label': 'match', 'score_id': 'n699', 'performance_id': '699'}
# {'label': 'match', 'score_id': 'n700', 'performance_id': '700'}
# {'label': 'match', 'score_id': 'n704', 'performance_id': '704'}
# {'label': 'deletion', 'score_id': 'n702'}
# {'label': 'match', 'score_id': 'n703', 'performance_id': '703'}
# {'label': 'match', 'score_id': 'n701', 'performance_id': '701'}
# {'label': 'match', 'score_id': 'n705', 'performance_id': '705'}
# {'label': 'match', 'score_id': 'n706', 'performance_id': '706'}
# {'label': 'match', 'score_id': 'n707', 'performance_id': '707'}
# {'label': 'match', 'score_id': 'n710', 'performance_id': '710'}
# {'label': 'match', 'score_id': 'n708', 'performance_id': '708'}
# {'label': 'match', 'score_id': 'n709', 'performance_id': '709'}
# {'label': 'match', 'score_id': 'n711', 'performance_id': '711'}
# {'label': 'match', 'score_id': 'n712', 'performance_id': '712'}
# {'label': 'match', 'score_id': 'n713', 'performance_id': '713'}
# {'label': 'match', 'score_id': 'n714', 'performance_id': '714'}
# {'label': 'match', 'score_id': 'n715', 'performance_id': '715'}
# {'label': 'match', 'score_id': 'n716', 'performance_id': '716'}
# {'label': 'match', 'score_id': 'n717', 'performance_id': '717'}
# {'label': 'match', 'score_id': 'n718', 'performance_id': '718'}
# {'label': 'match', 'score_id': 'n719', 'performance_id': '719'}
# {'label': 'match', 'score_id': 'n721', 'performance_id': '721'}
# {'label': 'match', 'score_id': 'n720', 'performance_id': '720'}
# {'label': 'match', 'score_id': 'n722', 'performance_id': '722'}
# {'label': 'match', 'score_id': 'n723', 'performance_id': '723'}
# {'label': 'match', 'score_id': 'n724', 'performance_id': '724'}
# {'label': 'match', 'score_id': 'n725', 'performance_id': '725'}
# {'label': 'match', 'score_id': 'n726', 'performance_id': '726'}
# {'label': 'match', 'score_id': 'n727', 'performance_id': '727'}
# {'label': 'match', 'score_id': 'n728', 'performance_id': '728'}
# {'label': 'match', 'score_id': 'n730', 'performance_id': '730'}
# {'label': 'match', 'score_id': 'n729', 'performance_id': '729'}
# {'label': 'match', 'score_id': 'n731', 'performance_id': '731'}
# {'label': 'match', 'score_id': 'n732', 'performance_id': '732'}
# {'label': 'match', 'score_id': 'n733', 'performance_id': '733'}
# {'label': 'match', 'score_id': 'n734', 'performance_id': '734'}
# {'label': 'match', 'score_id': 'n735', 'performance_id': '735'}
# {'label': 'match', 'score_id': 'n736', 'performance_id': '736'}
# {'label': 'match', 'score_id': 'n737', 'performance_id': '737'}
# {'label': 'match', 'score_id': 'n738', 'performance_id': '738'}
# {'label': 'match', 'score_id': 'n739', 'performance_id': '739'}
# {'label': 'match', 'score_id': 'n741', 'performance_id': '741'}
# {'label': 'match', 'score_id': 'n740', 'performance_id': '740'}
# ...
# {'label': 'deletion', 'score_id': 'n2797'}
# {'label': 'match', 'score_id': 'n2799', 'performance_id': '2799'}
# {'label': 'match', 'score_id': 'n2800', 'performance_id': '2800'}
# {'label': 'match', 'score_id': 'n2801', 'performance_id': '2801'}
# {'label': 'match', 'score_id': 'n2802', 'performance_id': '2802'}
# {'label': 'match', 'score_id': 'n2803', 'performance_id': '2803'}
# {'label': 'match', 'score_id': 'n2804', 'performance_id': '2804'}
# {'label': 'match', 'score_id': 'n2805', 'performance_id': '2805'}
# {'label': 'match', 'score_id': 'n2806', 'performance_id': '2806'}
# {'label': 'match', 'score_id': 'n2807', 'performance_id': '2807'}
# {'label': 'match', 'score_id': 'n2808', 'performance_id': '2808'}
# {'label': 'match', 'score_id': 'n2808', 'performance_id': '2809'}
# {'label': 'match', 'score_id': 'n2810', 'performance_id': '2810'}
# {'label': 'deletion', 'score_id': 'n2809'}
# {'label': 'match', 'score_id': 'n2811', 'performance_id': '2811'}
# {'label': 'match', 'score_id': 'n2812', 'performance_id': '2812'}
# {'label': 'match', 'score_id': 'n2813', 'performance_id': '2813'}
# {'label': 'match', 'score_id': 'n2816', 'performance_id': '2816'}
# {'label': 'match', 'score_id': 'n2814', 'performance_id': '2814'}
# {'label': 'match', 'score_id': 'n2817', 'performance_id': '2817'}
# {'label': 'match', 'score_id': 'n2817', 'performance_id': '2822'}
# {'label': 'match', 'score_id': 'n2815', 'performance_id': '2815'}
# {'label': 'match', 'score_id': 'n2818', 'performance_id': '2818'}
# {'label': 'match', 'score_id': 'n2819', 'performance_id': '2819'}
# {'label': 'match', 'score_id': 'n2820', 'performance_id': '2820'}
# {'label': 'match', 'score_id': 'n2821', 'performance_id': '2821'}
# {'label': 'match', 'score_id': 'n2821', 'performance_id': '2826'}
# {'label': 'deletion', 'score_id': 'n2822'}
# {'label': 'match', 'score_id': 'n2824', 'performance_id': '2824'}
# {'label': 'match', 'score_id': 'n2823', 'performance_id': '2823'}
# {'label': 'match', 'score_id': 'n2825', 'performance_id': '2825'}
# {'label': 'match', 'score_id': 'n2827', 'performance_id': '2827'}
# {'label': 'match', 'score_id': 'n2828', 'performance_id': '2828'}
# {'label': 'match', 'score_id': 'n2831', 'performance_id': '2831'}
# {'label': 'match', 'score_id': 'n2830', 'performance_id': '2830'}
# {'label': 'match', 'score_id': 'n2829', 'performance_id': '2829'}
# {'label': 'match', 'score_id': 'n2832', 'performance_id': '2832'}
# {'label': 'match', 'score_id': 'n2833', 'performance_id': '2833'}
# {'label': 'match', 'score_id': 'n2834', 'performance_id': '2834'}
# {'label': 'match', 'score_id': 'n2835', 'performance_id': '2835'}
# {'label': 'match', 'score_id': 'n2836', 'performance_id': '2836'}
# {'label': 'match', 'score_id': 'n2837', 'performance_id': '2837'}
# {'label': 'match', 'score_id': 'n2838', 'performance_id': '2838'}
# {'label': 'match', 'score_id': 'n2839', 'performance_id': '2839'}
# {'label': 'match', 'score_id': 'n2840', 'performance_id': '2840'}
# {'label': 'match', 'score_id': 'n2842', 'performance_id': '2842'}
# {'label': 'match', 'score_id': 'n2841', 'performance_id': '2841'}
# {'label': 'match', 'score_id': 'n2843', 'performance_id': '2843'}
# {'label': 'match', 'score_id': 'n2844', 'performance_id': '2844'}
# {'label': 'match', 'score_id': 'n2845', 'performance_id': '2845'}
# {'label': 'match', 'score_id': 'n2846', 'performance_id': '2846'}
# {'label': 'match', 'score_id': 'n2847', 'performance_id': '2847'}
# {'label': 'match', 'score_id': 'n2848', 'performance_id': '2848'}
# {'label': 'match', 'score_id': 'n2849', 'performance_id': '2849'}
# {'label': 'match', 'score_id': 'n2850', 'performance_id': '2850'}
# {'label': 'match', 'score_id': 'n2851', 'performance_id': '2851'}
# {'label': 'match', 'score_id': 'n2852', 'performance_id': '2852'}
# {'label': 'match', 'score_id': 'n2853', 'performance_id': '2853'}
# {'label': 'match', 'score_id': 'n2855', 'performance_id': '2855'}
# {'label': 'match', 'score_id': 'n2854', 'performance_id': '2854'}
# {'label': 'match', 'score_id': 'n2856', 'performance_id': '2856'}
# {'label': 'match', 'score_id': 'n2857', 'performance_id': '2857'}
# {'label': 'match', 'score_id': 'n2858', 'performance_id': '2858'}
# {'label': 'match', 'score_id': 'n2859', 'performance_id': '2859'}
# {'label': 'match', 'score_id': 'n2860', 'performance_id': '2860'}
# {'label': 'match', 'score_id': 'n2862', 'performance_id': '2862'}
# {'label': 'match', 'score_id': 'n2861', 'performance_id': '2861'}
# {'label': 'match', 'score_id': 'n2864', 'performance_id': '2864'}
# {'label': 'match', 'score_id': 'n2863', 'performance_id': '2863'}
# {'label': 'match', 'score_id': 'n2866', 'performance_id': '2866'}
# {'label': 'match', 'score_id': 'n2865', 'performance_id': '2865'}
# {'label': 'match', 'score_id': 'n2867', 'performance_id': '2867'}
# {'label': 'match', 'score_id': 'n2868', 'performance_id': '2868'}
# {'label': 'match', 'score_id': 'n2869', 'performance_id': '2869'}
# {'label': 'match', 'score_id': 'n2870', 'performance_id': '2870'}
# {'label': 'match', 'score_id': 'n2872', 'performance_id': '2872'}
# {'label': 'match', 'score_id': 'n2872', 'performance_id': '2877'}
# {'label': 'match', 'score_id': 'n2871', 'performance_id': '2871'}
# {'label': 'match', 'score_id': 'n2873', 'performance_id': '2873'}
# {'label': 'match', 'score_id': 'n2874', 'performance_id': '2874'}
# {'label': 'match', 'score_id': 'n2875', 'performance_id': '2875'}
# {'label': 'match', 'score_id': 'n2876', 'performance_id': '2876'}
# {'label': 'deletion', 'score_id': 'n2877'}
# {'label': 'match', 'score_id': 'n2879', 'performance_id': '2879'}
# {'label': 'match', 'score_id': 'n2878', 'performance_id': '2878'}
# {'label': 'match', 'score_id': 'n2880', 'performance_id': '2880'}
# {'label': 'match', 'score_id': 'n2881', 'performance_id': '2881'}
# {'label': 'match', 'score_id': 'n2882', 'performance_id': '2882'}
# {'label': 'match', 'score_id': 'n2884', 'performance_id': '2884'}
# {'label': 'match', 'score_id': 'n2883', 'performance_id': '2883'}
# {'label': 'match', 'score_id': 'n2885', 'performance_id': '2885'}
# {'label': 'match', 'score_id': 'n2886', 'performance_id': '2886'}
# {'label': 'match', 'score_id': 'n2887', 'performance_id': '2887'}
# {'label': 'match', 'score_id': 'n2888', 'performance_id': '2888'}
# {'label': 'match', 'score_id': 'n2889', 'performance_id': '2889'}
# {'label': 'match', 'score_id': 'n2890', 'performance_id': '2890'}
# {'label': 'match', 'score_id': 'n2891', 'performance_id': '2891'}
# {'label': 'match', 'score_id': 'n2892', 'performance_id': '2892'}
# {'label': 'match', 'score_id': 'n2893', 'performance_id': '2893'}
# {'label': 'match', 'score_id': 'n2894', 'performance_id': '2894'}
# {'label': 'match', 'score_id': 'n2895', 'performance_id': '2895'}
# {'label': 'match', 'score_id': 'n2896', 'performance_id': '2896'}
# {'label': 'match', 'score_id': 'n2897', 'performance_id': '2897'}
# {'label': 'match', 'score_id': 'n2898', 'performance_id': '2898'}
# {'label': 'match', 'score_id': 'n2899', 'performance_id': '2899'}
# {'label': 'match', 'score_id': 'n2900', 'performance_id': '2900'}
# {'label': 'match', 'score_id': 'n2901', 'performance_id': '2901'}
# {'label': 'match', 'score_id': 'n2902', 'performance_id': '2902'}
# {'label': 'match', 'score_id': 'n2903', 'performance_id': '2903'}
# {'label': 'match', 'score_id': 'n2905', 'performance_id': '2905'}
# {'label': 'match', 'score_id': 'n2904', 'performance_id': '2904'}
# {'label': 'deletion', 'score_id': 'n2906'}
# {'label': 'match', 'score_id': 'n2907', 'performance_id': '2907'}
# {'label': 'match', 'score_id': 'n2908', 'performance_id': '2906'}
# {'label': 'match', 'score_id': 'n2908', 'performance_id': '2908'}
# {'label': 'match', 'score_id': 'n2910', 'performance_id': '2910'}
# {'label': 'match', 'score_id': 'n2911', 'performance_id': '2911'}
# {'label': 'match', 'score_id': 'n2909', 'performance_id': '2909'}
# {'label': 'match', 'score_id': 'n2912', 'performance_id': '2912'}
# {'label': 'match', 'score_id': 'n2913', 'performance_id': '2913'}
# {'label': 'match', 'score_id': 'n2914', 'performance_id': '2914'}
# {'label': 'match', 'score_id': 'n2914', 'performance_id': '2917'}
# {'label': 'match', 'score_id': 'n2916', 'performance_id': '2916'}
# {'label': 'match', 'score_id': 'n2915', 'performance_id': '2915'}
# {'label': 'deletion', 'score_id': 'n2917'}
# {'label': 'match', 'score_id': 'n2918', 'performance_id': '2918'}
# {'label': 'match', 'score_id': 'n2919', 'performance_id': '2919'}
# {'label': 'match', 'score_id': 'n2920', 'performance_id': '2920'}
# {'label': 'match', 'score_id': 'n2921', 'performance_id': '2921'}
# {'label': 'match', 'score_id': 'n2922', 'performance_id': '2922'}
# {'label': 'match', 'score_id': 'n2923', 'performance_id': '2923'}
# {'label': 'match', 'score_id': 'n2924', 'performance_id': '2924'}
# {'label': 'match', 'score_id': 'n2924', 'performance_id': '2927'}
# {'label': 'match', 'score_id': 'n2925', 'performance_id': '2925'}
# {'label': 'deletion', 'score_id': 'n2927'}
# {'label': 'match', 'score_id': 'n2926', 'performance_id': '2926'}
# {'label': 'match', 'score_id': 'n2928', 'performance_id': '2928'}
# {'label': 'match', 'score_id': 'n2929', 'performance_id': '2929'}
# {'label': 'match', 'score_id': 'n2930', 'performance_id': '2930'}
# {'label': 'match', 'score_id': 'n2931', 'performance_id': '2931'}
# {'label': 'match', 'score_id': 'n2932', 'performance_id': '2932'}
# {'label': 'match', 'score_id': 'n2933', 'performance_id': '2933'}
# {'label': 'match', 'score_id': 'n2934', 'performance_id': '2934'}
# {'label': 'match', 'score_id': 'n2935', 'performance_id': '2935'}
# {'label': 'match', 'score_id': 'n2936', 'performance_id': '2936'}
# {'label': 'match', 'score_id': 'n2937', 'performance_id': '2937'}
# {'label': 'match', 'score_id': 'n2938', 'performance_id': '2938'}
# {'label': 'match', 'score_id': 'n2939', 'performance_id': '2939'}
# {'label': 'match', 'score_id': 'n2940', 'performance_id': '2940'}
# {'label': 'match', 'score_id': 'n2941', 'performance_id': '2941'}
# {'label': 'match', 'score_id': 'n2942', 'performance_id': '2942'}
# {'label': 'match', 'score_id': 'n2943', 'performance_id': '2943'}
# {'label': 'match', 'score_id': 'n2943', 'performance_id': '2944'}
# {'label': 'deletion', 'score_id': 'n2944'}
# {'label': 'match', 'score_id': 'n2945', 'performance_id': '2945'}
# {'label': 'match', 'score_id': 'n2946', 'performance_id': '2946'}
# {'label': 'match', 'score_id': 'n2947', 'performance_id': '2947'}
# {'label': 'match', 'score_id': 'n2948', 'performance_id': '2948'}
# {'label': 'match', 'score_id': 'n2949', 'performance_id': '2949'}
# {'label': 'match', 'score_id': 'n2950', 'performance_id': '2950'}
# {'label': 'match', 'score_id': 'n2952', 'performance_id': '2952'}
# {'label': 'match', 'score_id': 'n2951', 'performance_id': '2951'}
# {'label': 'match', 'score_id': 'n2951', 'performance_id': '2957'}
# {'label': 'match', 'score_id': 'n2953', 'performance_id': '2953'}
# {'label': 'match', 'score_id': 'n2954', 'performance_id': '2954'}
# {'label': 'match', 'score_id': 'n2955', 'performance_id': '2955'}
# {'label': 'match', 'score_id': 'n2959', 'performance_id': '2959'}
# {'label': 'match', 'score_id': 'n2958', 'performance_id': '2958'}
# {'label': 'match', 'score_id': 'n2956', 'performance_id': '2956'}
# {'label': 'deletion', 'score_id': 'n2957'}
# {'label': 'match', 'score_id': 'n2960', 'performance_id': '2960'}
# {'label': 'match', 'score_id': 'n2961', 'performance_id': '2961'}
# {'label': 'deletion', 'score_id': 'n2962'}
# {'label': 'match', 'score_id': 'n2966', 'performance_id': '2966'}
# {'label': 'match', 'score_id': 'n2965', 'performance_id': '2965'}
# {'label': 'match', 'score_id': 'n2964', 'performance_id': '2964'}
# {'label': 'match', 'score_id': 'n2963', 'performance_id': '2963'}
# {'label': 'insertion', 'performance_id': '50'}
# {'label': 'insertion', 'performance_id': '61'}
# {'label': 'insertion', 'performance_id': '91'}
# {'label': 'insertion', 'performance_id': '93'}
# {'label': 'insertion', 'performance_id': '108'}
# {'label': 'insertion', 'performance_id': '137'}
# {'label': 'insertion', 'performance_id': '266'}
# {'label': 'insertion', 'performance_id': '268'}
# {'label': 'insertion', 'performance_id': '295'}
# {'label': 'insertion', 'performance_id': '303'}
# {'label': 'insertion', 'performance_id': '309'}
# {'label': 'insertion', 'performance_id': '339'}
# {'label': 'insertion', 'performance_id': '380'}
# {'label': 'insertion', 'performance_id': '466'}
# {'label': 'insertion', 'performance_id': '475'}
# {'label': 'insertion', 'performance_id': '534'}
# {'label': 'insertion', 'performance_id': '537'}
# {'label': 'insertion', 'performance_id': '540'}
# {'label': 'insertion', 'performance_id': '639'}
# {'label': 'insertion', 'performance_id': '642'}
# {'label': 'insertion', 'performance_id': '643'}
# {'label': 'insertion', 'performance_id': '646'}
# {'label': 'insertion', 'performance_id': '650'}
# {'label': 'insertion', 'performance_id': '653'}
# {'label': 'insertion', 'performance_id': '753'}
# {'label': 'insertion', 'performance_id': '759'}
# {'label': 'insertion', 'performance_id': '803'}
# {'label': 'insertion', 'performance_id': '958'}
# {'label': 'insertion', 'performance_id': '1042'}
# {'label': 'insertion', 'performance_id': '1079'}
# {'label': 'insertion', 'performance_id': '1080'}
# {'label': 'insertion', 'performance_id': '1088'}
# {'label': 'insertion', 'performance_id': '1090'}
# {'label': 'insertion', 'performance_id': '1112'}
# {'label': 'insertion', 'performance_id': '1116'}
# {'label': 'insertion', 'performance_id': '1124'}
# {'label': 'insertion', 'performance_id': '1132'}
# {'label': 'insertion', 'performance_id': '1138'}
# {'label': 'insertion', 'performance_id': '1160'}
# {'label': 'insertion', 'performance_id': '1197'}
# {'label': 'insertion', 'performance_id': '1199'}
# {'label': 'insertion', 'performance_id': '1201'}
# {'label': 'insertion', 'performance_id': '1287'}
# {'label': 'insertion', 'performance_id': '1355'}
# {'label': 'insertion', 'performance_id': '1358'}
# {'label': 'insertion', 'performance_id': '1361'}
# {'label': 'insertion', 'performance_id': '1459'}
# {'label': 'insertion', 'performance_id': '1463'}
# {'label': 'insertion', 'performance_id': '1466'}
# {'label': 'insertion', 'performance_id': '1469'}
# {'label': 'insertion', 'performance_id': '1472'}
# {'label': 'insertion', 'performance_id': '1473'}
# {'label': 'insertion', 'performance_id': '1475'}
# {'label': 'insertion', 'performance_id': '1686'}
# {'label': 'insertion', 'performance_id': '1687'}
# {'label': 'insertion', 'performance_id': '1775'}
# {'label': 'insertion', 'performance_id': '1798'}
# {'label': 'insertion', 'performance_id': '1844'}
# {'label': 'insertion', 'performance_id': '1847'}
# {'label': 'insertion', 'performance_id': '1893'}
# {'label': 'insertion', 'performance_id': '1896'}
# {'label': 'insertion', 'performance_id': '1912'}
# {'label': 'insertion', 'performance_id': '1913'}
# {'label': 'insertion', 'performance_id': '1922'}
# {'label': 'insertion', 'performance_id': '1926'}
# {'label': 'insertion', 'performance_id': '2072'}
# {'label': 'insertion', 'performance_id': '2102'}
# {'label': 'insertion', 'performance_id': '2222'}
# {'label': 'insertion', 'performance_id': '2225'}
# {'label': 'insertion', 'performance_id': '2239'}
# {'label': 'insertion', 'performance_id': '2242'}
# {'label': 'insertion', 'performance_id': '2267'}
# {'label': 'insertion', 'performance_id': '2273'}
# {'label': 'insertion', 'performance_id': '2295'}
# {'label': 'insertion', 'performance_id': '2341'}
# {'label': 'insertion', 'performance_id': '2430'}
# {'label': 'insertion', 'performance_id': '2431'}
# {'label': 'insertion', 'performance_id': '2439'}
# {'label': 'insertion', 'performance_id': '2450'}
# {'label': 'insertion', 'performance_id': '2461'}
# {'label': 'insertion', 'performance_id': '2562'}
# {'label': 'insertion', 'performance_id': '2596'}
# {'label': 'insertion', 'performance_id': '2620'}
# {'label': 'insertion', 'performance_id': '2640'}
# {'label': 'insertion', 'performance_id': '2654'}
# {'label': 'insertion', 'performance_id': '2657'}
# {'label': 'insertion', 'performance_id': '2744'}
# {'label': 'insertion', 'performance_id': '2759'}
# {'label': 'insertion', 'performance_id': '2763'}
# {'label': 'insertion', 'performance_id': '2766'}
# {'label': 'insertion', 'performance_id': '2769'}
# {'label': 'insertion', 'performance_id': '2772'}
# {'label': 'insertion', 'performance_id': '2962'}

# %% [markdown]
# ### Alignment Methods
#
# * Which Method(s) did you use? (e.g., Dynamic Time Warping)
# * What is this method supposed to do (conceptually, you don't need to go into an in-depth description of the methods)
# * What were the hyper-parameters/settings of the method? (e.g., choice of local distance measure for DTW)
# * Is there any lesson you learned during the challenge

# %% [markdown]
# ## Evaluation
#
# * Describe the evaluation that you conducted designing the submissions.
# * Which things worked and which things didn't?

# %% [markdown]
# ## Conclusions
#
# * Is there anything interesting insight that you can conclude from the challenge?

# %% [markdown]
# ## References
#
# * Reference the papers used for this work!
# https://mpeg.chiariglione.org/standards/mpeg-4/symbolic-music-representation
